# %% [markdown]
# # Задание 2.2 - Введение в PyTorch
#
# Для этого задания потребуется установить версию PyTorch 1.0
#
# https://pytorch.org/get-started/locally/
#
# В этом задании мы познакомимся с основными компонентами PyTorch и натренируем несколько небольших моделей.<br>
# GPU нам пока не понадобится.
#
# Основные ссылки:
# https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html
# https://pytorch.org/docs/stable/nn.html
# https://pytorch.org/docs/stable/torchvision/index.html

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as dset
from torch.utils.data.sampler import SubsetRandomSampler, Sampler

from torchvision import transforms

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# %% [markdown]
# ## Как всегда, начинаем с загрузки данных
#
# PyTorch поддерживает загрузку SVHN из коробки.

# %%
# First, lets load the dataset
data_train = dset.SVHN('./data/', split='train',
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize(mean=[0.43,0.44,0.47],
                                               std=[0.20,0.20,0.20])                           
                       ])
                      )
data_test = dset.SVHN('./data/', split='test', 
                      transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize(mean=[0.43,0.44,0.47],
                                               std=[0.20,0.20,0.20])                           
                       ]))

# %% [markdown]
# Теперь мы разделим данные на training и validation с использованием классов `SubsetRandomSampler` и `DataLoader`.
#
# `DataLoader` подгружает данные, предоставляемые классом `Dataset`, во время тренировки и группирует их в батчи.
# Он дает возможность указать `Sampler`, который выбирает, какие примеры из датасета использовать для тренировки. Мы используем это, чтобы разделить данные на training и validation.
#
# Подробнее: https://pytorch.org/tutorials/beginner/data_loading_tutorial.html

# %%
batch_size = 64

data_size = data_train.data.shape[0]
validation_split = .2
split = int(np.floor(validation_split * data_size))
indices = list(range(data_size))
np.random.shuffle(indices)

train_indices, val_indices = indices[split:], indices[:split]

train_sampler = SubsetRandomSampler(train_indices)
val_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(data_train, batch_size=batch_size, 
                                           sampler=train_sampler)
val_loader = torch.utils.data.DataLoader(data_train, batch_size=batch_size,
                                         sampler=val_sampler)

# %% [markdown]
# В нашей задаче мы получаем на вход изображения, но работаем с ними как с одномерными массивами. Чтобы превратить многомерный массив в одномерный, мы воспользуемся очень простым вспомогательным модулем `Flattener`.

# %%
sample, label = data_train[0]
print("SVHN data sample shape: ", sample.shape)
# As you can see, the data is shaped like an image

# We'll use a special helper module to shape it into a tensor
class Flattener(nn.Module):
    def forward(self, x):
        batch_size, *_ = x.shape
        return x.view(batch_size, -1)
# Out:
# SVHN data sample shape:  torch.Size([3, 32, 32])

# %% [markdown]
# И наконец, мы создаем основные объекты PyTorch:
# - `nn_model` - собственно, модель с нейросетью
# - `loss` - функцию ошибки, в нашем случае `CrossEntropyLoss`
# - `optimizer` - алгоритм оптимизации, в нашем случае просто `SGD`

# %%
nn_model = nn.Sequential(Flattener(),
                         nn.Linear(3*32*32, 100),
                         nn.ReLU(inplace=True),
                         nn.Linear(100, 10))
nn_model.type(torch.FloatTensor)

# We will minimize cross-entropy between the ground truth and
# network predictions using an SGD optimizer
loss = nn.CrossEntropyLoss().type(torch.FloatTensor)
optimizer = optim.SGD(nn_model.parameters(), lr=1e-2, weight_decay=1e-1)

# %% [markdown]
# ## Тренируем!
#
# Ниже приведена функция `train_model`, реализующая основной цикл тренировки PyTorch.
#
# Каждую эпоху эта функция вызывает функцию `compute_accuracy`, которая вычисляет точность на validation, эту последнюю функцию предлагается реализовать вам.

# %%
# This is how to implement the same main train loop in PyTorch. Pretty easy, right?

def train_model(model, train_loader, val_loader, loss, optimizer, num_epochs): 
    loss_history = []
    train_history = []
    val_history = []
    for epoch in range(num_epochs):
        model.train() # Enter train mode
        loss_accum = 0
        correct_samples = 0
        total_samples = 0
        for i_step, (x, y) in enumerate(train_loader):
            prediction = nn_model(x)    
            loss_value = loss(prediction, y)
            optimizer.zero_grad()
            loss_value.backward()
            optimizer.step()
            
            _, indices = torch.max(prediction, 1)
            correct_samples += torch.sum(indices == y)
            total_samples += y.shape[0]
            
            loss_accum += loss_value

        ave_loss = loss_accum / i_step
        train_accuracy = float(correct_samples) / total_samples
        val_accuracy = compute_accuracy(model, val_loader)
        
        loss_history.append(float(ave_loss))
        train_history.append(train_accuracy)
        val_history.append(val_accuracy)
        
        print("Average loss: %f, Train accuracy: %f, Val accuracy: %f" % (ave_loss, train_accuracy, val_accuracy))
        
    return loss_history, train_history, val_history
        
def compute_accuracy(model, loader):
    """
    Computes accuracy on the dataset wrapped in a loader
    
    Returns: accuracy as a float value between 0 and 1
    """
    model.eval() # Evaluation mode
    val_accuracy = 0
    correct = 0
    total = 0
    for i_step, (x, y) in enumerate(loader):
        pred = nn_model(x)
        
        _, indices = torch.max(pred, 1)
        correct += torch.sum(indices == y)
        total += y.shape[0]
        
        val_accuracy = float(correct)/total
    # TODO: Implement the inference of the model on all of the batches from loader,
    #       and compute the overall accuracy.
    # Hint: torch doesn't have a dedicated argmax function,
    #       but you can use torch.max instead (see the documentation).
    
    #raise Exception("Not implemented")
    
    return val_accuracy

# %%
loss_history, train_history, val_history = train_model(nn_model, train_loader, val_loader, loss, optimizer, 4)
# Out:
# Average loss: 1.825771, Train accuracy: 0.406068, Val accuracy: 0.534435
# Average loss: 1.464734, Train accuracy: 0.576204, Val accuracy: 0.605624
# Average loss: 1.382609, Train accuracy: 0.619271, Val accuracy: 0.619275
# Average loss: 1.352125, Train accuracy: 0.633536, Val accuracy: 0.633813

# %% [markdown]
# ## После основного цикла
#
# Посмотрим на другие возможности и оптимизации, которые предоставляет PyTorch.
#
# Добавьте еще один скрытый слой размера 100 нейронов к модели

# %%
# Since it's so easy to add layers, let's add some!

# TODO: Implement a model with 2 hidden layers of the size 100 instead of 1
nn_model = nn.Sequential(Flattener(),
                         nn.Linear(3*32*32, 100),
                         nn.ReLU(inplace=True),
                         nn.Linear(100, 100),
                         nn.ReLU(inplace=True),
                         nn.Linear(100, 10))
nn_model.type(torch.FloatTensor)
optimizer = optim.SGD(nn_model.parameters(), lr=2e-2, weight_decay=1e-1)
loss_history, train_history, val_history = train_model(nn_model, train_loader, val_loader,loss, optimizer, 10)
# Out:
# Average loss: 2.117801, Train accuracy: 0.219858, Val accuracy: 0.286260
# Average loss: 1.810142, Train accuracy: 0.378562, Val accuracy: 0.428298
# Average loss: 1.702166, Train accuracy: 0.425315, Val accuracy: 0.438195
# Average loss: 1.686962, Train accuracy: 0.433266, Val accuracy: 0.448229
# Average loss: 1.677487, Train accuracy: 0.437686, Val accuracy: 0.443383
# Average loss: 1.673456, Train accuracy: 0.438675, Val accuracy: 0.438195
# Average loss: 1.672258, Train accuracy: 0.441712, Val accuracy: 0.447751
# Average loss: 1.670403, Train accuracy: 0.440245, Val accuracy: 0.443724
# Average loss: 1.670350, Train accuracy: 0.442139, Val accuracy: 0.442495
# Average loss: 1.669043, Train accuracy: 0.440194, Val accuracy: 0.394376

# %% [markdown]
# Добавьте слой с Batch Normalization

# %%
# We heard batch normalization is powerful, let's use it!
# TODO: Add batch normalization after each of the hidden layers of the network, before the non-linearity
# Hint: check out torch.nn.BatchNorm1d

nn_model = nn.Sequential(Flattener(),
                         nn.Linear(3*32*32, 100),
                         nn.BatchNorm1d(100),
                         nn.ReLU(inplace = True),
                         nn.Linear(100, 100),
                         nn.BatchNorm1d(100),
                         nn.ReLU(inplace = True),
                         nn.Linear(100, 10))

nn_model.type(torch.FloatTensor)
optimizer = optim.SGD(nn_model.parameters(), lr=2e-2, weight_decay=1e-1)
loss_history, train_history, val_history = train_model(nn_model, train_loader, val_loader,loss, optimizer, 10)
# Out:
# Average loss: 1.962743, Train accuracy: 0.349725, Val accuracy: 0.368166
# Average loss: 1.895607, Train accuracy: 0.387947, Val accuracy: 0.375606
# Average loss: 1.888519, Train accuracy: 0.393868, Val accuracy: 0.398949
# Average loss: 1.875924, Train accuracy: 0.398048, Val accuracy: 0.325302
# Average loss: 1.868960, Train accuracy: 0.402979, Val accuracy: 0.374309
# Average loss: 1.866257, Train accuracy: 0.402809, Val accuracy: 0.377995
# Average loss: 1.861585, Train accuracy: 0.404771, Val accuracy: 0.375947
# Average loss: 1.864155, Train accuracy: 0.402706, Val accuracy: 0.399768
# Average loss: 1.863149, Train accuracy: 0.403303, Val accuracy: 0.390827
# Average loss: 1.862154, Train accuracy: 0.402092, Val accuracy: 0.393557

# %% [markdown]
# Добавьте уменьшение скорости обучения по ходу тренировки.

# %%
def train_model_parametrized(model, train_loader, val_loader, loss, optimizer, num_epochs, step_size_shed, gam_shed): 
    sheduler = optim.lr_scheduler.StepLR(optimizer, step_size = step_size_shed, gamma = gam_shed)
    loss_history = []
    train_history = []
    val_history = []
    for epoch in range(num_epochs):
        model.train() # Enter train mode
        loss_accum = 0
        correct_samples = 0
        total_samples = 0
        sheduler.step()
        for i_step, (x, y) in enumerate(train_loader):
            prediction = nn_model(x)    
            loss_value = loss(prediction, y)
            optimizer.zero_grad()
            loss_value.backward()
            optimizer.step()
            
            _, indices = torch.max(prediction, 1)
            correct_samples += torch.sum(indices == y)
            total_samples += y.shape[0]
            
            loss_accum += loss_value

        ave_loss = loss_accum / i_step
        train_accuracy = float(correct_samples) / total_samples
        val_accuracy = compute_accuracy(model, val_loader)
        
        loss_history.append(float(ave_loss))
        train_history.append(train_accuracy)
        val_history.append(val_accuracy)
        
        print("Average loss: %f, Train accuracy: %f, Val accuracy: %f" % (ave_loss, train_accuracy, val_accuracy))
        
    return loss_history, train_history, val_history

# %%
# Learing rate annealing
# Reduce your learning rate 2x every 2 epochs
# Hint: look up learning rate schedulers in PyTorch. You might need to extend train_model function a little bit too!

nn_model = nn.Sequential(Flattener(),
                          nn.Linear(3*32*32, 100),
                          nn.BatchNorm1d(100),
                          nn.ReLU(inplace = True),
                          nn.Linear(100, 100),
                          nn.BatchNorm1d(100),
                          nn.ReLU(inplace = True),
                          nn.Linear(100, 10))
nn_model.type(torch.FloatTensor)
optimizer = optim.SGD(nn_model.parameters(), lr=2e-2, weight_decay=1e-1)
loss_history, train_history, val_history = train_model_parametrized(nn_model, train_loader, val_loader,loss, optimizer, 15, 2, 0.5)
# Out:
# Average loss: 1.966649, Train accuracy: 0.344999, Val accuracy: 0.415944
# Average loss: 1.883886, Train accuracy: 0.396717, Val accuracy: 0.368985
# Average loss: 1.830727, Train accuracy: 0.418746, Val accuracy: 0.436830
# Average loss: 1.812347, Train accuracy: 0.422960, Val accuracy: 0.430414
# Average loss: 1.761704, Train accuracy: 0.443095, Val accuracy: 0.452870
# Average loss: 1.751210, Train accuracy: 0.445262, Val accuracy: 0.451915
# Average loss: 1.711351, Train accuracy: 0.463502, Val accuracy: 0.471094
# Average loss: 1.706138, Train accuracy: 0.463894, Val accuracy: 0.472664
# Average loss: 1.676735, Train accuracy: 0.478296, Val accuracy: 0.478193
# Average loss: 1.671604, Train accuracy: 0.478620, Val accuracy: 0.448980
# Average loss: 1.652352, Train accuracy: 0.487066, Val accuracy: 0.492731
# Average loss: 1.649194, Train accuracy: 0.486759, Val accuracy: 0.486861
# Average loss: 1.638125, Train accuracy: 0.493038, Val accuracy: 0.495598
# Average loss: 1.635061, Train accuracy: 0.492868, Val accuracy: 0.498260
# Average loss: 1.628126, Train accuracy: 0.496895, Val accuracy: 0.503379

# %% [markdown]
# # Визуализируем ошибки модели
#
# Попробуем посмотреть, на каких изображениях наша модель ошибается.
# Для этого мы получим все предсказания модели на validation set и сравним их с истинными метками (ground truth).
#
# Первая часть - реализовать код на PyTorch, который вычисляет все предсказания модели на validation set.
# Чтобы это сделать мы приводим код `SubsetSampler`, который просто проходит по всем заданным индексам последовательно и составляет из них батчи.
#
# Реализуйте функцию `evaluate_model`, которая прогоняет модель через все сэмплы validation set и запоминает предсказания модели и истинные метки.

# %%
class SubsetSampler(Sampler):
    r"""Samples elements with given indices sequentially

    Arguments:
        data_source (Dataset): dataset to sample from
        indices (ndarray): indices of the samples to take
    """

    def __init__(self, indices):
        self.indices = indices

    def __iter__(self):
        return (self.indices[i] for i in range(len(self.indices)))

    def __len__(self):
        return len(self.indices)
    
    
def evaluate_model(model, dataset, indices):
    """
    Computes predictions and ground truth labels for the indices of the dataset
    
    Returns: 
    predictions: np array of booleans of model predictions
    grount_truth: np array of boolean of actual labels of the dataset
    """
    model.eval() # Evaluation mode
    loader = torch.utils.data.DataLoader(dataset, 
                                           sampler=SubsetSampler(indices))
    predictions = []
    ground_truth = []
    for i_step, (x, y) in enumerate(loader):
        pred = model(x)
        _, indices = torch.max(pred, 1)
        predictions.append(int(indices))
        ground_truth.append(int(y))
    # TODO: Evaluate model on the list of indices and capture predictions
    # and ground truth labels
    # Hint: SubsetSampler above could be useful!
    
    #raise Exception("Not implemented")
    
    return np.array(predictions), np.array(ground_truth)

# Evaluate model on validation

predictions, gt = evaluate_model(nn_model, data_train, val_indices)
assert len(predictions) == len(val_indices)
assert len(gt) == len(val_indices)
assert gt[100] == data_train[val_indices[100]][1]
assert np.any(np.not_equal(gt, predictions))

# %% [markdown]
# ## Confusion matrix
# Первая часть визуализации - вывести confusion matrix (https://en.wikipedia.org/wiki/Confusion_matrix ).
#
# Confusion matrix - это матрица, где каждой строке соответствуют классы предсказанный, а столбцу - классы истинных меток (ground truth). Число с координатами `i,j` - это количество сэмплов класса `j`, которые модель считает классом `i`.
#
# ![image.png](attachment:image.png)
#
# Для того, чтобы облегчить вам задачу, ниже реализована функция `visualize_confusion_matrix` которая визуализирует такую матрицу.
# Вам осталось реализовать функцию `build_confusion_matrix`, которая ее вычислит.
#
# Результатом должна быть матрица 10x10.

# %%
def visualize_confusion_matrix(confusion_matrix):
    """
    Visualizes confusion matrix
    
    confusion_matrix: np array of ints, x axis - predicted class, y axis - actual class
                      [i][j] should have the count of samples that were predicted to be class i,
                      but have j in the ground truth
                     
    """
    # Adapted from 
    # https://stackoverflow.com/questions/2897826/confusion-matrix-with-number-of-classified-misclassified-instances-on-it-python
    assert confusion_matrix.shape[0] == confusion_matrix.shape[1]
    size = confusion_matrix.shape[0]
    fig = plt.figure(figsize=(10,10))
    plt.title("Confusion matrix")
    plt.xlabel("predicted")
    plt.ylabel("ground truth")
    res = plt.imshow(confusion_matrix, cmap='GnBu', interpolation='nearest')
    cb = fig.colorbar(res)
    plt.xticks(np.arange(size))
    plt.yticks(np.arange(size))
    for i, row in enumerate(confusion_matrix):
        for j, count in enumerate(row):
            plt.text(j, i, count, fontsize=14, horizontalalignment='center', verticalalignment='center')
    
def build_confusion_matrix(predictions, ground_truth):
    """
    Builds confusion matrix from predictions and ground truth

    predictions: np array of ints, model predictions for all validation samples
    ground_truth: np array of ints, ground truth for all validation samples
    
    Returns:
    np array of ints, (10,10), counts of samples for predicted/ground_truth classes
    """
    
    confusion_matrix = np.zeros((10,10), np.int)
    for i in range(len(predictions)):
        confusion_matrix[ground_truth[i]][predictions[i]] += 1
    
    # TODO: Implement filling the prediction matrix
    return confusion_matrix
    #return np.array([[40, 2, 3], [10,50,0], [0, 2, 80]])

confusion_matrix = build_confusion_matrix(predictions, gt)
visualize_confusion_matrix(confusion_matrix)

# %% [markdown]
# Очень плохо определяем нули :(

# %% [markdown]
# Наконец, посмотрим на изображения, соответствующие некоторым элементам этой матрицы.
#
# Как и раньше, вам дана функция `visualize_images`, которой нужно воспрользоваться при реализации функции `visualize_predicted_actual`. Эта функция должна вывести несколько примеров, соответствующих заданному элементу матрицы.
#
# Визуализируйте наиболее частые ошибки и попробуйте понять, почему модель их совершает.

# %%
data_train_images = dset.SVHN('./data/', split='train')

def visualize_images(indices, data, title='', max_num=10):
    """
    Visualizes several images from the dataset
 
    indices: array of indices to visualize
    data: torch Dataset with the images
    title: string, title of the plot
    max_num: int, max number of images to display
    """
    to_show = min(len(indices), max_num)
    fig = plt.figure(figsize=(10,1.5))
    fig.suptitle(title)
    for i, index in enumerate(indices[:to_show]):
        plt.subplot(1,to_show, i+1)
        plt.axis('off')
        sample = data[index][0]
        plt.imshow(sample)
        
def visualize_predicted_actual(predicted_class, gt_class, predictions, ground_truth, val_indices, data):
    """
    Visualizes images of a ground truth class which were predicted as the other class 
    
    predicted: int 0-9, index of the predicted class
    gt_class: int 0-9, index of the ground truth class
    predictions: np array of ints, model predictions for all validation samples
    ground_truth: np array of ints, ground truth for all validation samples
    val_indices: np array of ints, indices of validation samples
    """
    # TODO: Implement visualization using visualize_images above
    # predictions and ground_truth are provided for validation set only, defined by val_indices
    # Hint: numpy index arrays might be helpful
    # https://docs.scipy.org/doc/numpy/user/basics.indexing.html#index-arrays
    # Please make the title meaningful!
    visualize_images(val_indices[np.logical_and(predictions == predicted_class, ground_truth == gt_class)], data)
    #raise Exception("Not implemented")
visualize_predicted_actual(6, 8, predictions, gt, np.array(val_indices), data_train_images)
visualize_predicted_actual(1, 7, predictions, gt, np.array(val_indices), data_train_images)
visualize_predicted_actual(3, 5, predictions, gt, np.array(val_indices), data_train_images)

# %% [markdown]
# # Переходим к свободным упражнениям!
#
# Натренируйте модель как можно лучше - экспериментируйте сами!
# Что следует обязательно попробовать:
# - перебор гиперпараметров с помощью валидационной выборки
# - другие оптимизаторы вместо SGD
# - изменение количества слоев и их размеров
# - наличие Batch Normalization
#
# Но ограничиваться этим не стоит!
#
# Точность на валидацонной выборке должна быть доведена до **60%**
#
# За лучший результат в группе вы получите дополнительные баллы :)

# %%
#with BatchNorm with neuron_size =200, and with Adam, and with 4 layer
lr_rates = [1e-4, 1e-3]
weight_decays = [1e-5, 1e-4]
neurons_nums = [100, 200]
num_epochs = 30
best_nn = (0,0)
best_val = -1
for neurons in neurons_nums:
    for wd in weight_decays:
        for lr in lr_rates:
            print(f'Parameters are lr={lr}, neurons={neurons}')
            nn_model = nn.Sequential(Flattener(),
                                     nn.Linear(3*32*32, neurons),
                                     nn.BatchNorm1d(neurons),
                                     nn.ReLU(inplace = True),
                                     nn.Linear(neurons, neurons),
                                     nn.BatchNorm1d(neurons),
                                     nn.ReLU(inplace = True),
                                     nn.Linear(neurons, 10))
            nn_model.type(torch.FloatTensor)
            optimizer = optim.Adam(nn_model.parameters(), lr=lr, weight_decay=wd)
            loss_history, train_history, val_history = train_model_parametrized(nn_model, train_loader, val_loader,loss, optimizer, num_epochs, 2, 0.5)
            if best_val < val_history[len(val_history)-1]:
                best_val = val_history[len(val_history)-1]
                best_nn = (nn_model, optimizer)
    print(f'Best accuracy is {best_val}')
# Out:
# Parameters are lr=0.0001, neurons=100
# Average loss: 1.773402, Train accuracy: 0.455329, Val accuracy: 0.620367
# Average loss: 1.212019, Train accuracy: 0.654916, Val accuracy: 0.700976
# Average loss: 0.960382, Train accuracy: 0.724721, Val accuracy: 0.750870
# Average loss: 0.870293, Train accuracy: 0.745862, Val accuracy: 0.767251
# Average loss: 0.792612, Train accuracy: 0.768522, Val accuracy: 0.775647
# Average loss: 0.764979, Train accuracy: 0.774068, Val accuracy: 0.785407
# Average loss: 0.729309, Train accuracy: 0.783981, Val accuracy: 0.793461
# Average loss: 0.718484, Train accuracy: 0.788264, Val accuracy: 0.793188
# Average loss: 0.701986, Train accuracy: 0.794543, Val accuracy: 0.796191
# Average loss: 0.693559, Train accuracy: 0.794646, Val accuracy: 0.798512
# Average loss: 0.687035, Train accuracy: 0.796250, Val accuracy: 0.800218
# Average loss: 0.682705, Train accuracy: 0.799236, Val accuracy: 0.800423
# Average loss: 0.679502, Train accuracy: 0.799372, Val accuracy: 0.801106
# Average loss: 0.678019, Train accuracy: 0.798911, Val accuracy: 0.802471
# Average loss: 0.674203, Train accuracy: 0.801181, Val accuracy: 0.802471
# Average loss: 0.675466, Train accuracy: 0.799850, Val accuracy: 0.801652
# Average loss: 0.675992, Train accuracy: 0.800020, Val accuracy: 0.803972
# Average loss: 0.675342, Train accuracy: 0.802205, Val accuracy: 0.802880
# Average loss: 0.673901, Train accuracy: 0.801676, Val accuracy: 0.803904
# Average loss: 0.674793, Train accuracy: 0.799765, Val accuracy: 0.801993
# Average loss: 0.671912, Train accuracy: 0.801437, Val accuracy: 0.803426
# Average loss: 0.672064, Train accuracy: 0.800822, Val accuracy: 0.803768
# Average loss: 0.673634, Train accuracy: 0.801061, Val accuracy: 0.804314
# Average loss: 0.672662, Train accuracy: 0.799799, Val accuracy: 0.801720
# Average loss: 0.674103, Train accuracy: 0.801164, Val accuracy: 0.802744
# Average loss: 0.672400, Train accuracy: 0.801744, Val accuracy: 0.802130
# Average loss: 0.670864, Train accuracy: 0.803365, Val accuracy: 0.803563
# Average loss: 0.671434, Train accuracy: 0.802665, Val accuracy: 0.804314
# Average loss: 0.669837, Train accuracy: 0.801488, Val accuracy: 0.803358
# Average loss: 0.672805, Train accuracy: 0.800515, Val accuracy: 0.802266
# Parameters are lr=0.001, neurons=100
# Average loss: 1.390793, Train accuracy: 0.547743, Val accuracy: 0.680363
# Average loss: 0.941762, Train accuracy: 0.703409, Val accuracy: 0.760016
# Average loss: 0.758177, Train accuracy: 0.764495, Val accuracy: 0.783496
# Average loss: 0.704367, Train accuracy: 0.780023, Val accuracy: 0.786636
# Average loss: 0.634203, Train accuracy: 0.802665, Val accuracy: 0.809092
# Average loss: 0.615487, Train accuracy: 0.808740, Val accuracy: 0.810320
# Average loss: 0.576593, Train accuracy: 0.822117, Val accuracy: 0.820422
# Average loss: 0.563671, Train accuracy: 0.823107, Val accuracy: 0.823289
# Average loss: 0.547318, Train accuracy: 0.829847, Val accuracy: 0.827247
# Average loss: 0.545425, Train accuracy: 0.831280, Val accuracy: 0.827179
# Average loss: 0.533286, Train accuracy: 0.834642, Val accuracy: 0.828135
# Average loss: 0.528421, Train accuracy: 0.834642, Val accuracy: 0.830592
# Average loss: 0.527813, Train accuracy: 0.834846, Val accuracy: 0.827316
# Average loss: 0.522701, Train accuracy: 0.835853, Val accuracy: 0.827998
# Average loss: 0.519139, Train accuracy: 0.838737, Val accuracy: 0.830114
# Average loss: 0.522123, Train accuracy: 0.837645, Val accuracy: 0.831479
# Average loss: 0.519782, Train accuracy: 0.839146, Val accuracy: 0.829500
# Average loss: 0.520030, Train accuracy: 0.838617, Val accuracy: 0.829295
# Average loss: 0.519858, Train accuracy: 0.837713, Val accuracy: 0.829568
# Average loss: 0.517469, Train accuracy: 0.839812, Val accuracy: 0.831889
# Average loss: 0.516477, Train accuracy: 0.840631, Val accuracy: 0.829568
# Average loss: 0.517985, Train accuracy: 0.838395, Val accuracy: 0.831684
# Average loss: 0.521667, Train accuracy: 0.837696, Val accuracy: 0.831479
# Average loss: 0.519931, Train accuracy: 0.839129, Val accuracy: 0.831001
# Average loss: 0.518583, Train accuracy: 0.839266, Val accuracy: 0.833117
# Average loss: 0.517098, Train accuracy: 0.839743, Val accuracy: 0.831411
# Average loss: 0.520214, Train accuracy: 0.839010, Val accuracy: 0.831957
# Average loss: 0.517612, Train accuracy: 0.838054, Val accuracy: 0.831206
# Average loss: 0.518970, Train accuracy: 0.839846, Val accuracy: 0.831479
# Average loss: 0.515374, Train accuracy: 0.841586, Val accuracy: 0.831343
# Parameters are lr=0.0001, neurons=100
# Average loss: 1.749600, Train accuracy: 0.470651, Val accuracy: 0.592110
# Average loss: 1.199738, Train accuracy: 0.659540, Val accuracy: 0.703774
# Average loss: 0.948930, Train accuracy: 0.727553, Val accuracy: 0.752440
# Average loss: 0.849514, Train accuracy: 0.752278, Val accuracy: 0.763088
# Average loss: 0.772636, Train accuracy: 0.774579, Val accuracy: 0.782336
# Average loss: 0.738679, Train accuracy: 0.784066, Val accuracy: 0.789502
# Average loss: 0.709324, Train accuracy: 0.791284, Val accuracy: 0.797352
# Average loss: 0.694832, Train accuracy: 0.796386, Val accuracy: 0.796464
# Average loss: 0.679022, Train accuracy: 0.799526, Val accuracy: 0.801720
# Average loss: 0.672717, Train accuracy: 0.802307, Val accuracy: 0.803290
# Average loss: 0.662940, Train accuracy: 0.806249, Val accuracy: 0.804655
# Average loss: 0.661977, Train accuracy: 0.806453, Val accuracy: 0.804041
# Average loss: 0.657456, Train accuracy: 0.807750, Val accuracy: 0.807863
# Average loss: 0.656091, Train accuracy: 0.807818, Val accuracy: 0.807999
# Average loss: 0.652402, Train accuracy: 0.808586, Val accuracy: 0.806225
# Average loss: 0.652930, Train accuracy: 0.807579, Val accuracy: 0.807249
# Average loss: 0.651664, Train accuracy: 0.808808, Val accuracy: 0.807385
# Average loss: 0.652619, Train accuracy: 0.807852, Val accuracy: 0.807044
# Average loss: 0.651782, Train accuracy: 0.808143, Val accuracy: 0.805747
# Average loss: 0.650483, Train accuracy: 0.809303, Val accuracy: 0.805747
# Average loss: 0.649169, Train accuracy: 0.810497, Val accuracy: 0.808545
# Average loss: 0.651118, Train accuracy: 0.808586, Val accuracy: 0.805884
# Average loss: 0.650537, Train accuracy: 0.807904, Val accuracy: 0.807522
# Average loss: 0.650733, Train accuracy: 0.810310, Val accuracy: 0.808545
# Average loss: 0.650031, Train accuracy: 0.808910, Val accuracy: 0.804791
# Average loss: 0.649424, Train accuracy: 0.809252, Val accuracy: 0.806703
# Average loss: 0.648144, Train accuracy: 0.810804, Val accuracy: 0.806430
# Average loss: 0.649575, Train accuracy: 0.809627, Val accuracy: 0.805542
# Average loss: 0.649972, Train accuracy: 0.808177, Val accuracy: 0.808136
# Average loss: 0.647292, Train accuracy: 0.809985, Val accuracy: 0.809638
# Parameters are lr=0.001, neurons=100
# Average loss: 1.395896, Train accuracy: 0.543903, Val accuracy: 0.692308
# Average loss: 0.950389, Train accuracy: 0.701191, Val accuracy: 0.751553
# Average loss: 0.764616, Train accuracy: 0.761048, Val accuracy: 0.764316
# Average loss: 0.706889, Train accuracy: 0.779494, Val accuracy: 0.792369
# Average loss: 0.633547, Train accuracy: 0.803689, Val accuracy: 0.810525
# Average loss: 0.611522, Train accuracy: 0.810122, Val accuracy: 0.817965
# Average loss: 0.572593, Train accuracy: 0.822851, Val accuracy: 0.823835
# Average loss: 0.557360, Train accuracy: 0.826502, Val accuracy: 0.827043
# Average loss: 0.537488, Train accuracy: 0.833498, Val accuracy: 0.831001
# Average loss: 0.532698, Train accuracy: 0.835307, Val accuracy: 0.831411
# Average loss: 0.522802, Train accuracy: 0.839624, Val accuracy: 0.833595
# Average loss: 0.520513, Train accuracy: 0.840102, Val accuracy: 0.834619
# Average loss: 0.516696, Train accuracy: 0.840579, Val accuracy: 0.835643
# Average loss: 0.515680, Train accuracy: 0.841945, Val accuracy: 0.834755
# Average loss: 0.510270, Train accuracy: 0.842047, Val accuracy: 0.835984
# Average loss: 0.507324, Train accuracy: 0.843719, Val accuracy: 0.835097
# Average loss: 0.505637, Train accuracy: 0.844009, Val accuracy: 0.835438
# Average loss: 0.508624, Train accuracy: 0.841296, Val accuracy: 0.835779
# Average loss: 0.503581, Train accuracy: 0.844487, Val accuracy: 0.835301
# Average loss: 0.505899, Train accuracy: 0.844163, Val accuracy: 0.835097
# Average loss: 0.506601, Train accuracy: 0.843105, Val accuracy: 0.834278
# Average loss: 0.503983, Train accuracy: 0.844538, Val accuracy: 0.835370
# Average loss: 0.504439, Train accuracy: 0.844077, Val accuracy: 0.835165
# Average loss: 0.504599, Train accuracy: 0.843975, Val accuracy: 0.835574
# Average loss: 0.503003, Train accuracy: 0.845272, Val accuracy: 0.837690
# Average loss: 0.504554, Train accuracy: 0.843975, Val accuracy: 0.835779
# Average loss: 0.503828, Train accuracy: 0.844265, Val accuracy: 0.836462
# Average loss: 0.503518, Train accuracy: 0.844572, Val accuracy: 0.835301
# Average loss: 0.503607, Train accuracy: 0.845579, Val accuracy: 0.837622
# Average loss: 0.505230, Train accuracy: 0.843651, Val accuracy: 0.835847
# Best accuracy is 0.8358473824312334
# Parameters are lr=0.0001, neurons=200
# Average loss: 1.529491, Train accuracy: 0.552674, Val accuracy: 0.687462
# Average loss: 0.994893, Train accuracy: 0.708801, Val accuracy: 0.748891
# Average loss: 0.793954, Train accuracy: 0.763335, Val accuracy: 0.785066
# Average loss: 0.724172, Train accuracy: 0.780569, Val accuracy: 0.801584
# Average loss: 0.651535, Train accuracy: 0.804713, Val accuracy: 0.813665
# Average loss: 0.623109, Train accuracy: 0.813705, Val accuracy: 0.819398
# Average loss: 0.590631, Train accuracy: 0.823806, Val accuracy: 0.825746
# Average loss: 0.577477, Train accuracy: 0.829079, Val accuracy: 0.827452
# Average loss: 0.562016, Train accuracy: 0.832782, Val accuracy: 0.829295
# Average loss: 0.559039, Train accuracy: 0.833242, Val accuracy: 0.829909
# Average loss: 0.548860, Train accuracy: 0.838890, Val accuracy: 0.832230
# Average loss: 0.546875, Train accuracy: 0.838327, Val accuracy: 0.833731
# Average loss: 0.543473, Train accuracy: 0.839812, Val accuracy: 0.831547
# Average loss: 0.540510, Train accuracy: 0.839982, Val accuracy: 0.833595
# Average loss: 0.539023, Train accuracy: 0.839573, Val accuracy: 0.833117
# Average loss: 0.537299, Train accuracy: 0.839846, Val accuracy: 0.833458
# Average loss: 0.537460, Train accuracy: 0.841723, Val accuracy: 0.831343
# Average loss: 0.537685, Train accuracy: 0.840068, Val accuracy: 0.834960
# Average loss: 0.535986, Train accuracy: 0.841330, Val accuracy: 0.835097
# Average loss: 0.539476, Train accuracy: 0.840306, Val accuracy: 0.834892
# Average loss: 0.537103, Train accuracy: 0.842098, Val accuracy: 0.835165
# Average loss: 0.533892, Train accuracy: 0.842832, Val accuracy: 0.833254
# Average loss: 0.537005, Train accuracy: 0.840341, Val accuracy: 0.833322
# Average loss: 0.535327, Train accuracy: 0.841672, Val accuracy: 0.834892
# Average loss: 0.536318, Train accuracy: 0.841774, Val accuracy: 0.835574
# Average loss: 0.536899, Train accuracy: 0.840562, Val accuracy: 0.836189
# Average loss: 0.536295, Train accuracy: 0.840477, Val accuracy: 0.835097
# Average loss: 0.534634, Train accuracy: 0.841979, Val accuracy: 0.833936
# Average loss: 0.534550, Train accuracy: 0.842030, Val accuracy: 0.835643
# Average loss: 0.533986, Train accuracy: 0.842115, Val accuracy: 0.835643
# Parameters are lr=0.001, neurons=200
# Average loss: 1.306151, Train accuracy: 0.577176, Val accuracy: 0.695652
# Average loss: 0.877283, Train accuracy: 0.725523, Val accuracy: 0.757900
# Average loss: 0.688116, Train accuracy: 0.786780, Val accuracy: 0.793598
# Average loss: 0.641065, Train accuracy: 0.799918, Val accuracy: 0.801106
# Average loss: 0.560425, Train accuracy: 0.827031, Val accuracy: 0.826701
# Average loss: 0.539227, Train accuracy: 0.833225, Val accuracy: 0.825882
# Average loss: 0.500341, Train accuracy: 0.844896, Val accuracy: 0.838441
# Average loss: 0.483377, Train accuracy: 0.850357, Val accuracy: 0.840830
# Average loss: 0.461551, Train accuracy: 0.858752, Val accuracy: 0.842195
# Average loss: 0.452924, Train accuracy: 0.860253, Val accuracy: 0.842673
# Average loss: 0.442712, Train accuracy: 0.864502, Val accuracy: 0.846154
# Average loss: 0.437703, Train accuracy: 0.865133, Val accuracy: 0.843628
# Average loss: 0.434024, Train accuracy: 0.867778, Val accuracy: 0.846632
# Average loss: 0.432211, Train accuracy: 0.868717, Val accuracy: 0.848611
# Average loss: 0.427342, Train accuracy: 0.869604, Val accuracy: 0.848611
# Average loss: 0.429718, Train accuracy: 0.869297, Val accuracy: 0.847382
# Average loss: 0.424172, Train accuracy: 0.870372, Val accuracy: 0.847178
# Average loss: 0.426921, Train accuracy: 0.868836, Val accuracy: 0.847792
# Average loss: 0.425938, Train accuracy: 0.870372, Val accuracy: 0.848543
# Average loss: 0.422944, Train accuracy: 0.870730, Val accuracy: 0.846017
# Average loss: 0.423284, Train accuracy: 0.870082, Val accuracy: 0.849021
# Average loss: 0.424926, Train accuracy: 0.870235, Val accuracy: 0.849157
# Average loss: 0.422615, Train accuracy: 0.871225, Val accuracy: 0.847655
# Average loss: 0.424172, Train accuracy: 0.869911, Val accuracy: 0.848611
# Average loss: 0.423582, Train accuracy: 0.869536, Val accuracy: 0.847724
# Average loss: 0.424768, Train accuracy: 0.870201, Val accuracy: 0.848270
# Average loss: 0.423165, Train accuracy: 0.870611, Val accuracy: 0.846905
# Average loss: 0.425744, Train accuracy: 0.869007, Val accuracy: 0.846768
# Average loss: 0.423389, Train accuracy: 0.869160, Val accuracy: 0.847997
# Average loss: 0.422145, Train accuracy: 0.871174, Val accuracy: 0.847792
# Parameters are lr=0.0001, neurons=200
# Average loss: 1.555021, Train accuracy: 0.543784, Val accuracy: 0.680363
# Average loss: 1.014452, Train accuracy: 0.702402, Val accuracy: 0.739335
# Average loss: 0.800695, Train accuracy: 0.761304, Val accuracy: 0.780288
# Average loss: 0.727766, Train accuracy: 0.781353, Val accuracy: 0.794417
# Average loss: 0.659434, Train accuracy: 0.803706, Val accuracy: 0.803972
# Average loss: 0.630358, Train accuracy: 0.812340, Val accuracy: 0.811958
# Average loss: 0.596892, Train accuracy: 0.823397, Val accuracy: 0.816190
# Average loss: 0.587148, Train accuracy: 0.823875, Val accuracy: 0.818374
# Average loss: 0.569995, Train accuracy: 0.830410, Val accuracy: 0.825063
# Average loss: 0.563310, Train accuracy: 0.832577, Val accuracy: 0.825950
# Average loss: 0.556377, Train accuracy: 0.834454, Val accuracy: 0.826701
# Average loss: 0.552001, Train accuracy: 0.835921, Val accuracy: 0.828066
# Average loss: 0.548401, Train accuracy: 0.838191, Val accuracy: 0.828885
# Average loss: 0.545868, Train accuracy: 0.839453, Val accuracy: 0.828612
# Average loss: 0.546072, Train accuracy: 0.838430, Val accuracy: 0.827862
# Average loss: 0.545209, Train accuracy: 0.839180, Val accuracy: 0.827793
# Average loss: 0.542674, Train accuracy: 0.838037, Val accuracy: 0.829295
# Average loss: 0.544749, Train accuracy: 0.837901, Val accuracy: 0.828203
# Average loss: 0.543777, Train accuracy: 0.837047, Val accuracy: 0.825063
# Average loss: 0.541236, Train accuracy: 0.840972, Val accuracy: 0.828066
# Average loss: 0.541932, Train accuracy: 0.839522, Val accuracy: 0.828817
# Average loss: 0.540878, Train accuracy: 0.838276, Val accuracy: 0.831001
# Average loss: 0.540701, Train accuracy: 0.839061, Val accuracy: 0.828817
# Average loss: 0.542159, Train accuracy: 0.839709, Val accuracy: 0.830387
# Average loss: 0.539639, Train accuracy: 0.841416, Val accuracy: 0.827384
# Average loss: 0.539902, Train accuracy: 0.840409, Val accuracy: 0.828339
# Average loss: 0.540632, Train accuracy: 0.841091, Val accuracy: 0.830865
# Average loss: 0.541594, Train accuracy: 0.839641, Val accuracy: 0.827998
# Average loss: 0.539824, Train accuracy: 0.841296, Val accuracy: 0.830182
# Average loss: 0.539918, Train accuracy: 0.840852, Val accuracy: 0.829022
# Parameters are lr=0.001, neurons=200
# Average loss: 1.313644, Train accuracy: 0.574975, Val accuracy: 0.693536
# Average loss: 0.895529, Train accuracy: 0.719704, Val accuracy: 0.751143
# Average loss: 0.708084, Train accuracy: 0.779357, Val accuracy: 0.784656
# Average loss: 0.663212, Train accuracy: 0.793434, Val accuracy: 0.796601
# Average loss: 0.577712, Train accuracy: 0.820923, Val accuracy: 0.829568
# Average loss: 0.554547, Train accuracy: 0.828123, Val accuracy: 0.829227
# Average loss: 0.513487, Train accuracy: 0.841381, Val accuracy: 0.838714
# Average loss: 0.500423, Train accuracy: 0.845494, Val accuracy: 0.841308
# Average loss: 0.474743, Train accuracy: 0.853735, Val accuracy: 0.843628
# Average loss: 0.466681, Train accuracy: 0.856789, Val accuracy: 0.840693
# Average loss: 0.456892, Train accuracy: 0.859741, Val accuracy: 0.845062
# Average loss: 0.449784, Train accuracy: 0.862181, Val accuracy: 0.848475
# Average loss: 0.444745, Train accuracy: 0.864092, Val accuracy: 0.849225
# Average loss: 0.441701, Train accuracy: 0.863871, Val accuracy: 0.847587
# Average loss: 0.438322, Train accuracy: 0.865065, Val accuracy: 0.848338
# Average loss: 0.437183, Train accuracy: 0.866174, Val accuracy: 0.847382
# Average loss: 0.435089, Train accuracy: 0.866635, Val accuracy: 0.847724
# Average loss: 0.435993, Train accuracy: 0.865799, Val accuracy: 0.848406
# Average loss: 0.434886, Train accuracy: 0.866942, Val accuracy: 0.847860
# Average loss: 0.433367, Train accuracy: 0.867624, Val accuracy: 0.849089
# Average loss: 0.432150, Train accuracy: 0.867078, Val accuracy: 0.849430
# Average loss: 0.433958, Train accuracy: 0.867215, Val accuracy: 0.847860
# Average loss: 0.432783, Train accuracy: 0.867317, Val accuracy: 0.847109
# Average loss: 0.432656, Train accuracy: 0.867880, Val accuracy: 0.847997
# Average loss: 0.431454, Train accuracy: 0.867863, Val accuracy: 0.848065
# Average loss: 0.432009, Train accuracy: 0.866857, Val accuracy: 0.848952
# Average loss: 0.434237, Train accuracy: 0.867266, Val accuracy: 0.849498
# Average loss: 0.431763, Train accuracy: 0.866345, Val accuracy: 0.847928
# Average loss: 0.434156, Train accuracy: 0.866225, Val accuracy: 0.849976
# Average loss: 0.431682, Train accuracy: 0.866857, Val accuracy: 0.848338
# Best accuracy is 0.8483379974063204

# %%
predictions, gt = evaluate_model(best_nn[0], data_train, val_indices)
confusion_matrix = build_confusion_matrix(predictions, gt)
visualize_confusion_matrix(confusion_matrix)

# %%
# Как всегда, в конце проверяем на test set
test_loader = torch.utils.data.DataLoader(data_test, batch_size=batch_size)
test_accuracy = compute_accuracy(best_nn[0], test_loader)
print("Test accuracy: %2.4f" % test_accuracy)
# Out:
# Test accuracy: 0.8296

# %%
#Further exploration of number of neurons influense

neurons_num = 200
num_epochs = 30
nn_model = nn.Sequential(Flattener(),
                         nn.Linear(3*32*32, neurons_num),
                         nn.BatchNorm1d(neurons_num),
                         nn.ReLU(inplace = True),
                         nn.Linear(neurons_num, neurons_num),
                         nn.BatchNorm1d(neurons_num),
                         nn.ReLU(inplace = True),
                         nn.Linear(neurons_num, 10))
nn_model.type(torch.FloatTensor)
optimizer = optim.Adam(nn_model.parameters(), lr=1e-2, weight_decay=1e-3)
loss = nn.CrossEntropyLoss().type(torch.FloatTensor)
loss_history, train_history, val_history = train_model_parametrized(nn_model, train_loader, val_loader,loss, optimizer, num_epochs, 2, 0.5)
# Out:
# Average loss: 1.507999, Train accuracy: 0.494489, Val accuracy: 0.603850
# Average loss: 1.261876, Train accuracy: 0.597499, Val accuracy: 0.639615
# Average loss: 1.134583, Train accuracy: 0.644149, Val accuracy: 0.663982
# Average loss: 1.102517, Train accuracy: 0.654745, Val accuracy: 0.696744
# Average loss: 1.005586, Train accuracy: 0.689042, Val accuracy: 0.709644
# Average loss: 0.985699, Train accuracy: 0.696362, Val accuracy: 0.685619
# Average loss: 0.915992, Train accuracy: 0.721377, Val accuracy: 0.746707
# Average loss: 0.898834, Train accuracy: 0.724585, Val accuracy: 0.739335
# Average loss: 0.857353, Train accuracy: 0.740146, Val accuracy: 0.753327
# Average loss: 0.848161, Train accuracy: 0.742603, Val accuracy: 0.755580
# Average loss: 0.822891, Train accuracy: 0.751595, Val accuracy: 0.761928
# Average loss: 0.817307, Train accuracy: 0.753268, Val accuracy: 0.763975
# Average loss: 0.808087, Train accuracy: 0.757380, Val accuracy: 0.766159
# Average loss: 0.800790, Train accuracy: 0.759564, Val accuracy: 0.768616
# Average loss: 0.793375, Train accuracy: 0.762140, Val accuracy: 0.772917
# Average loss: 0.790692, Train accuracy: 0.763079, Val accuracy: 0.772097
# Average loss: 0.787165, Train accuracy: 0.763591, Val accuracy: 0.771551
# Average loss: 0.784498, Train accuracy: 0.764632, Val accuracy: 0.772644
# Average loss: 0.783544, Train accuracy: 0.766031, Val accuracy: 0.771347
# Average loss: 0.783639, Train accuracy: 0.766082, Val accuracy: 0.772644
# Average loss: 0.781839, Train accuracy: 0.765621, Val accuracy: 0.775374
# Average loss: 0.778397, Train accuracy: 0.766833, Val accuracy: 0.771688
# Average loss: 0.781794, Train accuracy: 0.766474, Val accuracy: 0.772712
# Average loss: 0.781784, Train accuracy: 0.764410, Val accuracy: 0.774145
# Average loss: 0.779926, Train accuracy: 0.765741, Val accuracy: 0.774418
# Average loss: 0.780362, Train accuracy: 0.766167, Val accuracy: 0.770391
# Average loss: 0.781178, Train accuracy: 0.765485, Val accuracy: 0.772575
# Average loss: 0.778434, Train accuracy: 0.765297, Val accuracy: 0.772029
# Average loss: 0.777248, Train accuracy: 0.768164, Val accuracy: 0.771551
# Average loss: 0.780079, Train accuracy: 0.767003, Val accuracy: 0.772302

# %%
#Add another fully connected layer

neurons_num = 200
nn_model = nn.Sequential(Flattener(),
                         nn.Linear(3*32*32, neurons_num),
                         nn.BatchNorm1d(neurons_num),
                         nn.ReLU(inplace = True),
                         nn.Linear(neurons_num, neurons_num),
                         nn.BatchNorm1d(neurons_num),
                         nn.ReLU(inplace = True),
                         nn.Linear(neurons_num, neurons_num),
                         nn.BatchNorm1d(neurons_num),
                         nn.ReLU(inplace = True),
                         nn.Linear(neurons_num, 10))

nn_model.type(torch.FloatTensor)
optimizer = optim.Adam(nn_model.parameters(), lr=1e-3, weight_decay=1e-3)
loss_history, train_history, val_history = train_model_parametrized(nn_model, train_loader, val_loader,loss, optimizer, num_epochs, 5, 0.5)
# Out:
# Average loss: 1.331840, Train accuracy: 0.561171, Val accuracy: 0.684117
# Average loss: 0.962614, Train accuracy: 0.694707, Val accuracy: 0.722954
# Average loss: 0.857381, Train accuracy: 0.729328, Val accuracy: 0.744864
# Average loss: 0.793723, Train accuracy: 0.749428, Val accuracy: 0.758651
# Average loss: 0.743933, Train accuracy: 0.764905, Val accuracy: 0.776466
# Average loss: 0.633266, Train accuracy: 0.802000, Val accuracy: 0.813869
# Average loss: 0.603302, Train accuracy: 0.811026, Val accuracy: 0.803836
# Average loss: 0.591859, Train accuracy: 0.816009, Val accuracy: 0.811549
# Average loss: 0.577169, Train accuracy: 0.818483, Val accuracy: 0.819808
# Average loss: 0.562547, Train accuracy: 0.823397, Val accuracy: 0.813187
# Average loss: 0.499826, Train accuracy: 0.843480, Val accuracy: 0.838851
# Average loss: 0.484382, Train accuracy: 0.848036, Val accuracy: 0.839397
# Average loss: 0.481180, Train accuracy: 0.848497, Val accuracy: 0.844174
# Average loss: 0.471702, Train accuracy: 0.851995, Val accuracy: 0.843014
# Average loss: 0.464867, Train accuracy: 0.854401, Val accuracy: 0.841717
# Average loss: 0.424663, Train accuracy: 0.866823, Val accuracy: 0.850522
# Average loss: 0.415517, Train accuracy: 0.869228, Val accuracy: 0.853594
# Average loss: 0.409547, Train accuracy: 0.870508, Val accuracy: 0.841513
# Average loss: 0.405558, Train accuracy: 0.873255, Val accuracy: 0.854617
# Average loss: 0.401337, Train accuracy: 0.874825, Val accuracy: 0.852638
# Average loss: 0.378982, Train accuracy: 0.882367, Val accuracy: 0.860556
# Average loss: 0.371400, Train accuracy: 0.884159, Val accuracy: 0.859122
# Average loss: 0.369415, Train accuracy: 0.884432, Val accuracy: 0.859737
# Average loss: 0.365651, Train accuracy: 0.886070, Val accuracy: 0.862330
# Average loss: 0.363372, Train accuracy: 0.886718, Val accuracy: 0.859668
# Average loss: 0.350782, Train accuracy: 0.891632, Val accuracy: 0.861375
# Average loss: 0.346450, Train accuracy: 0.892571, Val accuracy: 0.862467
# Average loss: 0.347225, Train accuracy: 0.891854, Val accuracy: 0.863695
# Average loss: 0.341668, Train accuracy: 0.895233, Val accuracy: 0.862876
# Average loss: 0.339117, Train accuracy: 0.895011, Val accuracy: 0.864514

# %%
predictions, gt = evaluate_model(nn_model, data_train, val_indices)
confusion_matrix = build_confusion_matrix(predictions, gt)
visualize_confusion_matrix(confusion_matrix)

# %%
# Как всегда, в конце проверяем на test set
test_loader = torch.utils.data.DataLoader(data_test, batch_size=batch_size)
test_accuracy = compute_accuracy(nn_model, test_loader)
print("Test accuracy: %2.4f" % test_accuracy)
# Out:
# Test accuracy: 0.8425

# %%
##Let's see how this nn will handle with data without batchnorm
neurons_num = 200
nn_model = nn.Sequential(Flattener(),
                         nn.Linear(3*32*32, neurons_num),
                         nn.ReLU(inplace = True),
                         nn.Linear(neurons_num, neurons_num),
                         nn.ReLU(inplace = True),
                         nn.Linear(neurons_num, neurons_num),
                         nn.ReLU(inplace = True),
                         nn.Linear(neurons_num, 10))
nn_model.type(torch.FloatTensor)
optimizer = optim.Adam(nn_model.parameters(), lr=1e-3, weight_decay=1e-3)
loss_history, train_history, val_history = train_model_parametrized(nn_model, train_loader, val_loader,loss, optimizer, num_epochs, 5, 0.5)
# Out:
# Average loss: 1.236868, Train accuracy: 0.596185, Val accuracy: 0.688554
# Average loss: 0.925319, Train accuracy: 0.707931, Val accuracy: 0.699679
# Average loss: 0.842152, Train accuracy: 0.736051, Val accuracy: 0.736264
# Average loss: 0.789002, Train accuracy: 0.752176, Val accuracy: 0.754693
# Average loss: 0.756682, Train accuracy: 0.763028, Val accuracy: 0.754078
# Average loss: 0.604809, Train accuracy: 0.813074, Val accuracy: 0.803017
# Average loss: 0.581246, Train accuracy: 0.819387, Val accuracy: 0.790731
# Average loss: 0.563535, Train accuracy: 0.823806, Val accuracy: 0.797215
# Average loss: 0.550845, Train accuracy: 0.827782, Val accuracy: 0.810047
# Average loss: 0.530246, Train accuracy: 0.834607, Val accuracy: 0.796874
# Average loss: 0.441109, Train accuracy: 0.865287, Val accuracy: 0.831547
# Average loss: 0.424380, Train accuracy: 0.871174, Val accuracy: 0.832162
# Average loss: 0.412707, Train accuracy: 0.872283, Val accuracy: 0.831070
# Average loss: 0.407018, Train accuracy: 0.875627, Val accuracy: 0.835028
# Average loss: 0.396269, Train accuracy: 0.877965, Val accuracy: 0.834755
# Average loss: 0.339817, Train accuracy: 0.897826, Val accuracy: 0.845335
# Average loss: 0.330636, Train accuracy: 0.900966, Val accuracy: 0.845881
# Average loss: 0.322942, Train accuracy: 0.902348, Val accuracy: 0.845335
# Average loss: 0.318399, Train accuracy: 0.905027, Val accuracy: 0.844720
# Average loss: 0.312328, Train accuracy: 0.906238, Val accuracy: 0.846632
# Average loss: 0.279588, Train accuracy: 0.919565, Val accuracy: 0.849840
# Average loss: 0.273516, Train accuracy: 0.920810, Val accuracy: 0.851751
# Average loss: 0.269146, Train accuracy: 0.923182, Val accuracy: 0.849840
# Average loss: 0.265333, Train accuracy: 0.923694, Val accuracy: 0.849567
# Average loss: 0.260421, Train accuracy: 0.925332, Val accuracy: 0.849976
# Average loss: 0.243881, Train accuracy: 0.930980, Val accuracy: 0.853389
# Average loss: 0.240634, Train accuracy: 0.933010, Val accuracy: 0.853525
# Average loss: 0.237844, Train accuracy: 0.933249, Val accuracy: 0.853525
# Average loss: 0.235959, Train accuracy: 0.934768, Val accuracy: 0.852638
# Average loss: 0.233334, Train accuracy: 0.935382, Val accuracy: 0.853252

# %%
predictions, gt = evaluate_model(nn_model, data_train, val_indices)
confusion_matrix = build_confusion_matrix(predictions, gt)
visualize_confusion_matrix(confusion_matrix)

# %%
test_loader = torch.utils.data.DataLoader(data_test, batch_size=batch_size)
test_accuracy = compute_accuracy(nn_model, test_loader)
print("Test accuracy: %2.4f" % test_accuracy)
# Out:
# Test accuracy: 0.8304
