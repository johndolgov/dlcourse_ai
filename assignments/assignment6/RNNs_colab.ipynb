# %% [markdown]
# # Задание 6: Рекуррентные нейронные сети (RNNs)
#
# Это задание адаптиповано из Deep NLP Course at ABBYY (https://github.com/DanAnastasyev/DeepNLP-Course) с разрешения автора - Даниила Анастасьева. Спасибо ему огромное!

# %%
# !pip3 -qq install torch==0.4.1
# !pip3 -qq install bokeh==0.13.0
# !pip3 -qq install gensim==3.6.0
# !pip3 -qq install nltk
# !pip3 -qq install scikit-learn==0.20.2

# %%
device = torch.device("cuda:0") # Let's make sure GPU is available!

# %%
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


if torch.cuda.is_available():
    from torch.cuda import FloatTensor, LongTensor
else:
    from torch import FloatTensor, LongTensor

np.random.seed(42)

# %% [markdown]
# # Рекуррентные нейронные сети (RNNs)

# %% [markdown]
# ## POS Tagging

# %% [markdown]
# Мы рассмотрим применение рекуррентных сетей к задаче sequence labeling (последняя картинка).
#
# ![RNN types](http://karpathy.github.io/assets/rnn/diags.jpeg)
#
# *From [The Unreasonable Effectiveness of Recurrent Neural Networks](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)*
#
# Самые популярные примеры для такой постановки задачи - Part-of-Speech Tagging и Named Entity Recognition.
#
# Мы порешаем сейчас POS Tagging для английского.
#
# Будем работать с таким набором тегов:
# - ADJ - adjective (new, good, high, ...)
# - ADP - adposition (on, of, at, ...)
# - ADV - adverb (really, already, still, ...)
# - CONJ - conjunction (and, or, but, ...)
# - DET - determiner, article (the, a, some, ...)
# - NOUN - noun (year, home, costs, ...)
# - NUM - numeral (twenty-four, fourth, 1991, ...)
# - PRT - particle (at, on, out, ...)
# - PRON - pronoun (he, their, her, ...)
# - VERB - verb (is, say, told, ...)
# - . - punctuation marks (. , ;)
# - X - other (ersatz, esprit, dunno, ...)

# %% [markdown]
# Скачаем данные:

# %%
import nltk
from sklearn.model_selection import train_test_split

nltk.download('brown')
nltk.download('universal_tagset')

data = nltk.corpus.brown.tagged_sents(tagset='universal')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %% [markdown]
# Пример размеченного предложения:

# %%
for word, tag in data[0]:
    print('{:15}\t{}'.format(word, tag))
# Out:
# The            	DET
# Fulton         	NOUN
# County         	NOUN
# Grand          	ADJ
# Jury           	NOUN
# said           	VERB
# Friday         	NOUN
# an             	DET
# investigation  	NOUN
# of             	ADP
# Atlanta's      	NOUN
# recent         	ADJ
# primary        	NOUN
# election       	NOUN
# produced       	VERB
# ``             	.
# no             	DET
# evidence       	NOUN
# ''             	.
# that           	ADP
# any            	DET
# irregularities 	NOUN
# took           	VERB
# place          	NOUN
# .              	.

# %% [markdown]
# Построим разбиение на train/val/test - наконец-то, всё как у нормальных людей.
#
# На train будем учиться, по val - подбирать параметры и делать всякие early stopping, а на test - принимать модель по ее финальному качеству.

# %%
train_data, test_data = train_test_split(data, test_size=0.25, random_state=42)
train_data, val_data = train_test_split(train_data, test_size=0.15, random_state=42)

print('Words count in train set:', sum(len(sent) for sent in train_data))
print('Words count in val set:', sum(len(sent) for sent in val_data))
print('Words count in test set:', sum(len(sent) for sent in test_data))
# Out:
# Words count in train set: 739769
# Words count in val set: 130954
# Words count in test set: 290469

# %% [markdown]
# Построим маппинги из слов в индекс и из тега в индекс:

# %%
words = {word for sample in train_data for word, tag in sample}
word2ind = {word: ind + 1 for ind, word in enumerate(words)}
word2ind['<pad>'] = 0

tags = {tag for sample in train_data for word, tag in sample}
tag2ind = {tag: ind + 1 for ind, tag in enumerate(tags)}
tag2ind['<pad>'] = 0


print('Unique words in train = {}. Tags = {}'.format(len(word2ind), tags))
# Out:
# Unique words in train = 45441. Tags = {'DET', '.', 'ADP', 'PRT', 'CONJ', 'NUM', 'NOUN', 'ADV', 'X', 'VERB', 'ADJ', 'PRON'}

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from collections import Counter

tag_distribution = Counter(tag for sample in train_data for _, tag in sample)
tag_distribution = [tag_distribution[tag] for tag in tags]

plt.figure(figsize=(10, 5))

bar_width = 0.35
plt.bar(np.arange(len(tags)), tag_distribution, bar_width, align='center', alpha=0.5)
plt.xticks(np.arange(len(tags)), tags)
    
plt.show()

# %% [markdown]
# ## Бейзлайн
#
# Какой самый простой теггер можно придумать? Давайте просто запоминать, какие теги самые вероятные для слова (или для последовательности):
#
# ![tag-context](https://www.nltk.org/images/tag-context.png)
# *From [Categorizing and Tagging Words, nltk](https://www.nltk.org/book/ch05.html)*
#
# На картинке показано, что для предсказания $t_n$ используются два предыдущих предсказанных тега + текущее слово. По корпусу считаются вероятность для $P(t_n| w_n, t_{n-1}, t_{n-2})$, выбирается тег с максимальной вероятностью.
#
# Более аккуратно такая идея реализована в Hidden Markov Models: по тренировочному корпусу вычисляются вероятности $P(w_n| t_n), P(t_n|t_{n-1}, t_{n-2})$ и максимизируется их произведение.
#
# Простейший вариант - униграммная модель, учитывающая только слово:

# %%
import nltk

default_tagger = nltk.DefaultTagger('NN')

unigram_tagger = nltk.UnigramTagger(train_data, backoff=default_tagger)
print('Accuracy of unigram tagger = {:.2%}'.format(unigram_tagger.evaluate(test_data)))
# Out:
# Accuracy of unigram tagger = 92.62%

# %% [markdown]
# Добавим вероятности переходов:

# %%
bigram_tagger = nltk.BigramTagger(train_data, backoff=unigram_tagger)
print('Accuracy of bigram tagger = {:.2%}'.format(bigram_tagger.evaluate(test_data)))
# Out:
# Accuracy of bigram tagger = 93.42%

# %% [markdown]
# Обратите внимание, что `backoff` важен:

# %%
trigram_tagger = nltk.TrigramTagger(train_data)
print('Accuracy of trigram tagger = {:.2%}'.format(trigram_tagger.evaluate(test_data)))
# Out:
# Accuracy of trigram tagger = 23.33%

# %% [markdown]
# ## Увеличиваем контекст с рекуррентными сетями
#
# Униграмная модель работает на удивление хорошо, но мы же собрались учить сеточки.
#
# Омонимия - основная причина, почему униграмная модель плоха:
# *“he cashed a check at the **bank**”*
# vs
# *“he sat on the **bank** of the river”*
#
# Поэтому нам очень полезно учитывать контекст при предсказании тега.
#
# Воспользуемся LSTM - он умеет работать с контекстом очень даже хорошо:
#
# ![](https://image.ibb.co/kgmoff/Baseline-Tagger.png)
#
# Синим показано выделение фичей из слова, LSTM оранжевенький - он строит эмбеддинги слов с учетом контекста, а дальше зелененькая логистическая регрессия делает предсказания тегов.

# %%
def convert_data(data, word2ind, tag2ind):
    X = [[word2ind.get(word, 0) for word, _ in sample] for sample in data]
    y = [[tag2ind[tag] for _, tag in sample] for sample in data]
    
    return X, y

X_train, y_train = convert_data(train_data, word2ind, tag2ind)
X_val, y_val = convert_data(val_data, word2ind, tag2ind)
X_test, y_test = convert_data(test_data, word2ind, tag2ind)

# %%
def iterate_batches(data, batch_size):
    X, y = data
    n_samples = len(X)

    indices = np.arange(n_samples)
    np.random.shuffle(indices)
    
    for start in range(0, n_samples, batch_size):
        end = min(start + batch_size, n_samples)
        
        batch_indices = indices[start:end]
        
        max_sent_len = max(len(X[ind]) for ind in batch_indices)
        X_batch = np.zeros((max_sent_len, len(batch_indices)))
        y_batch = np.zeros((max_sent_len, len(batch_indices)))
        
        for batch_ind, sample_ind in enumerate(batch_indices):
            X_batch[:len(X[sample_ind]), batch_ind] = X[sample_ind]
            y_batch[:len(y[sample_ind]), batch_ind] = y[sample_ind]
            
        yield X_batch, y_batch

# %%
X_batch, y_batch = next(iterate_batches((X_train, y_train), 4))

X_batch.shape, y_batch.shape
# Out:
# ((32, 4), (32, 4))

# %% [markdown]
# **Задание** Реализуйте `LSTMTagger`:

# %%
class LSTMTagger(nn.Module):
    def __init__(self, vocab_size, tagset_size, word_emb_dim=100, lstm_hidden_dim=128, lstm_layers_count=1):
        super().__init__()
        
        self._emb = nn.Embedding(vocab_size, word_emb_dim)
        self._lstm = nn.LSTM(word_emb_dim, lstm_hidden_dim, num_layers=lstm_layers_count)
        self._out_layer = nn.Linear(lstm_hidden_dim, tagset_size)

    def forward(self, inputs):
        print("Inputs: ", inputs.shape)
        emb = self._emb(inputs)
        print("Emb: ", emb.shape)
        output, _ = self._lstm(emb)
        print("Output of LSTM: ", output.shape)
        out = self._out_layer(output)
        print("Final output", out.shape)
        return out

# %% [markdown]
# **Задание** Научитесь считать accuracy и loss (а заодно проверьте, что модель работает)

# %%
model = LSTMTagger(
    vocab_size=len(word2ind),
    tagset_size=len(tag2ind)
)

X_batch, y_batch = torch.LongTensor(X_batch), torch.LongTensor(y_batch)

logits = model(X_batch)

preds = torch.argmax(logits, dim=-1)

mask = (y_batch != 0).float()
correct_count = ((preds == y_batch).float() * mask).sum().item()
total_count = mask.sum().item()

correct_count / total_count
# Out:
# Inputs:  torch.Size([32, 4])
# Emb:  torch.Size([32, 4, 100])
# Output of LSTM:  torch.Size([32, 4, 128])
# Final output torch.Size([32, 4, 13])
# 0.05434782608695652

# %%
criterion = nn.CrossEntropyLoss(ignore_index = 0).type(torch.cuda.FloatTensor)
logits = model(X_batch)
loss = 0
for ind, row in enumerate(logits):
    loss += criterion(row, y_batch[ind])
print(loss)
# Out:
# Inputs:  torch.Size([32, 4])
# Emb:  torch.Size([32, 4, 100])
# Output of LSTM:  torch.Size([32, 4, 128])
# Final output torch.Size([32, 4, 13])
# tensor(81.5770, grad_fn=<ThAddBackward>)

# %% [markdown]
# **Задание** Вставьте эти вычисление в функцию:

# %%
import math
from tqdm import tqdm


def do_epoch(model, criterion, data, batch_size, optimizer=None, name=None):
    epoch_loss = 0
    correct_count = 0
    sum_count = 0
    
    is_train = not optimizer is None
    name = name or ''
    model.train(is_train)
    
    batches_count = math.ceil(len(data[0]) / batch_size)
    
    with torch.autograd.set_grad_enabled(is_train):
        with tqdm(total=batches_count) as progress_bar:
            for i, (X_batch, y_batch) in enumerate(iterate_batches(data, batch_size)):
                X_batch, y_batch = LongTensor(X_batch), LongTensor(y_batch)
                logits = model(X_batch)

                loss = 0
                for ind, row in enumerate(logits):
                    loss += criterion(row, y_batch[ind])
                

                epoch_loss += loss.item()

                if optimizer:
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()
                
                
                preds = torch.argmax(logits, dim=-1)
                mask = (y_batch != 0).float()
                
                cur_correct_count, cur_sum_count = ((preds == y_batch).float() * mask).sum().item(), mask.sum().item()

                correct_count += cur_correct_count
                sum_count += cur_sum_count

                progress_bar.update()
                progress_bar.set_description('{:>5s} Loss = {:.5f}, Accuracy = {:.2%}'.format(
                    name, loss.item(), cur_correct_count / cur_sum_count)
                )
                
            progress_bar.set_description('{:>5s} Loss = {:.5f}, Accuracy = {:.2%}'.format(
                name, epoch_loss / batches_count, correct_count / sum_count)
            )

    return epoch_loss / batches_count, correct_count / sum_count


def fit(model, criterion, optimizer, train_data, epochs_count=1, batch_size=32,
        val_data=None, val_batch_size=None):
        
    if not val_data is None and val_batch_size is None:
        val_batch_size = batch_size
        
    for epoch in range(epochs_count):
        name_prefix = '[{} / {}] '.format(epoch + 1, epochs_count)
        train_loss, train_acc = do_epoch(model, criterion, train_data, batch_size, optimizer, name_prefix + 'Train:')
        
        if not val_data is None:
            val_loss, val_acc = do_epoch(model, criterion, val_data, val_batch_size, None, name_prefix + '  Val:')

# %%
model = LSTMTagger(
    lstm_layers_count=2,
    vocab_size=len(word2ind),
    tagset_size=len(tag2ind)
).cuda()

criterion = nn.CrossEntropyLoss(ignore_index = 0).cuda()
optimizer = optim.Adam(model.parameters(), lr = 5e-3, weight_decay = 5e-4)

fit(model, criterion, optimizer, train_data=(X_train, y_train), epochs_count=50, batch_size=64, val_data=(X_val, y_val), val_batch_size=512)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Masking
#
# **Задание** Проверьте себя - не считаете ли вы потери и accuracy на паддингах - очень легко получить высокое качество за счет этого.
#
# У функции потерь есть параметр `ignore_index`, для таких целей. Для accuracy нужно использовать маскинг - умножение на маску из нулей и единиц, где нули на позициях паддингов (а потом усреднение по ненулевым позициям в маске).

# %% [markdown]
# **Задание** Посчитайте качество модели на тесте. Ожидается результат лучше бейзлайна!

# %%
def compute_accuracy(model, data, batch_size=64):
    """
    Computes accuracy on the dataset wrapped in a loader
    
    Returns: accuracy as a float value between 0 and 1
    """
    model.eval() # Evaluation mode
    val_accuracy = 0
    correct = 0
    total = 0
    for i, (X_batch, y_batch) in enumerate(iterate_batches(data, batch_size)):
        X_batch, y_batch = LongTensor(X_batch), LongTensor(y_batch)
        logits = model(X_batch)
        
        pred = torch.argmax(logits, dim=-1)
        
        mask = (y_batch != 0).float()
        
        correct += ((pred == y_batch).float() * mask).sum().item()
        
        total += mask.sum().item()        
        
    val_accuracy = float(correct)/total
        
    return val_accuracy

test_ac =  compute_accuracy(model, (X_test, y_test))
print(f'Test accuracy is {test_ac * 100} %')
# Out:
# Inputs:  torch.Size([41, 64])
# Emb:  torch.Size([41, 64, 100])
# Output of LSTM:  torch.Size([41, 64, 128])
# Final output torch.Size([41, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 128])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 128])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([76, 64])
# Emb:  torch.Size([76, 64, 100])
# Output of LSTM:  torch.Size([76, 64, 128])
# Final output torch.Size([76, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([113, 64])
# Emb:  torch.Size([113, 64, 100])
# Output of LSTM:  torch.Size([113, 64, 128])
# Final output torch.Size([113, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 128])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([105, 64])
# Emb:  torch.Size([105, 64, 100])
# Output of LSTM:  torch.Size([105, 64, 128])
# Final output torch.Size([105, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 128])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 128])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([78, 64])
# Emb:  torch.Size([78, 64, 100])
# Output of LSTM:  torch.Size([78, 64, 128])
# Final output torch.Size([78, 64, 13])
# Inputs:  torch.Size([42, 64])
# Emb:  torch.Size([42, 64, 100])
# Output of LSTM:  torch.Size([42, 64, 128])
# Final output torch.Size([42, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([82, 64])
# Emb:  torch.Size([82, 64, 100])
# Output of LSTM:  torch.Size([82, 64, 128])
# Final output torch.Size([82, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([82, 64])
# Emb:  torch.Size([82, 64, 100])
# Output of LSTM:  torch.Size([82, 64, 128])
# Final output torch.Size([82, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([85, 64])
# Emb:  torch.Size([85, 64, 100])
# Output of LSTM:  torch.Size([85, 64, 128])
# Final output torch.Size([85, 64, 13])
# Inputs:  torch.Size([59, 64])
# Emb:  torch.Size([59, 64, 100])
# Output of LSTM:  torch.Size([59, 64, 128])
# Final output torch.Size([59, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([47, 64])
# Emb:  torch.Size([47, 64, 100])
# Output of LSTM:  torch.Size([47, 64, 128])
# Final output torch.Size([47, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([43, 64])
# Emb:  torch.Size([43, 64, 100])
# Output of LSTM:  torch.Size([43, 64, 128])
# Final output torch.Size([43, 64, 13])
# Inputs:  torch.Size([64, 64])
# Emb:  torch.Size([64, 64, 100])
# Output of LSTM:  torch.Size([64, 64, 128])
# Final output torch.Size([64, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 128])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([82, 64])
# Emb:  torch.Size([82, 64, 100])
# Output of LSTM:  torch.Size([82, 64, 128])
# Final output torch.Size([82, 64, 13])
# Inputs:  torch.Size([141, 64])
# Emb:  torch.Size([141, 64, 100])
# Output of LSTM:  torch.Size([141, 64, 128])
# Final output torch.Size([141, 64, 13])
# Inputs:  torch.Size([172, 64])
# Emb:  torch.Size([172, 64, 100])
# Output of LSTM:  torch.Size([172, 64, 128])
# Final output torch.Size([172, 64, 13])
# Inputs:  torch.Size([43, 64])
# Emb:  torch.Size([43, 64, 100])
# Output of LSTM:  torch.Size([43, 64, 128])
# Final output torch.Size([43, 64, 13])
# Inputs:  torch.Size([54, 64])
# Emb:  torch.Size([54, 64, 100])
# Output of LSTM:  torch.Size([54, 64, 128])
# Final output torch.Size([54, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([72, 64])
# Emb:  torch.Size([72, 64, 100])
# Output of LSTM:  torch.Size([72, 64, 128])
# Final output torch.Size([72, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 128])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([96, 64])
# Emb:  torch.Size([96, 64, 100])
# Output of LSTM:  torch.Size([96, 64, 128])
# Final output torch.Size([96, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([70, 64])
# Emb:  torch.Size([70, 64, 100])
# Output of LSTM:  torch.Size([70, 64, 128])
# Final output torch.Size([70, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 128])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([80, 64])
# Emb:  torch.Size([80, 64, 100])
# Output of LSTM:  torch.Size([80, 64, 128])
# Final output torch.Size([80, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 128])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([44, 64])
# Emb:  torch.Size([44, 64, 100])
# Output of LSTM:  torch.Size([44, 64, 128])
# Final output torch.Size([44, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([43, 64])
# Emb:  torch.Size([43, 64, 100])
# Output of LSTM:  torch.Size([43, 64, 128])
# Final output torch.Size([43, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([81, 64])
# Emb:  torch.Size([81, 64, 100])
# Output of LSTM:  torch.Size([81, 64, 128])
# Final output torch.Size([81, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 128])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([96, 64])
# Emb:  torch.Size([96, 64, 100])
# Output of LSTM:  torch.Size([96, 64, 128])
# Final output torch.Size([96, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([84, 64])
# Emb:  torch.Size([84, 64, 100])
# Output of LSTM:  torch.Size([84, 64, 128])
# Final output torch.Size([84, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 128])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([70, 64])
# Emb:  torch.Size([70, 64, 100])
# Output of LSTM:  torch.Size([70, 64, 128])
# Final output torch.Size([70, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([59, 64])
# Emb:  torch.Size([59, 64, 100])
# Output of LSTM:  torch.Size([59, 64, 128])
# Final output torch.Size([59, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([72, 64])
# Emb:  torch.Size([72, 64, 100])
# Output of LSTM:  torch.Size([72, 64, 128])
# Final output torch.Size([72, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([81, 64])
# Emb:  torch.Size([81, 64, 100])
# Output of LSTM:  torch.Size([81, 64, 128])
# Final output torch.Size([81, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 128])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 128])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([81, 64])
# Emb:  torch.Size([81, 64, 100])
# Output of LSTM:  torch.Size([81, 64, 128])
# Final output torch.Size([81, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 128])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 128])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 128])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([46, 64])
# Emb:  torch.Size([46, 64, 100])
# Output of LSTM:  torch.Size([46, 64, 128])
# Final output torch.Size([46, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 128])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([46, 64])
# Emb:  torch.Size([46, 64, 100])
# Output of LSTM:  torch.Size([46, 64, 128])
# Final output torch.Size([46, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([70, 64])
# Emb:  torch.Size([70, 64, 100])
# Output of LSTM:  torch.Size([70, 64, 128])
# Final output torch.Size([70, 64, 13])
# Inputs:  torch.Size([54, 64])
# Emb:  torch.Size([54, 64, 100])
# Output of LSTM:  torch.Size([54, 64, 128])
# Final output torch.Size([54, 64, 13])
# Inputs:  torch.Size([79, 64])
# Emb:  torch.Size([79, 64, 100])
# Output of LSTM:  torch.Size([79, 64, 128])
# Final output torch.Size([79, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([146, 64])
# Emb:  torch.Size([146, 64, 100])
# Output of LSTM:  torch.Size([146, 64, 128])
# Final output torch.Size([146, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([46, 64])
# Emb:  torch.Size([46, 64, 100])
# Output of LSTM:  torch.Size([46, 64, 128])
# Final output torch.Size([46, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([75, 64])
# Emb:  torch.Size([75, 64, 100])
# Output of LSTM:  torch.Size([75, 64, 128])
# Final output torch.Size([75, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([90, 64])
# Emb:  torch.Size([90, 64, 100])
# Output of LSTM:  torch.Size([90, 64, 128])
# Final output torch.Size([90, 64, 13])
# Inputs:  torch.Size([84, 64])
# Emb:  torch.Size([84, 64, 100])
# Output of LSTM:  torch.Size([84, 64, 128])
# Final output torch.Size([84, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([102, 64])
# Emb:  torch.Size([102, 64, 100])
# Output of LSTM:  torch.Size([102, 64, 128])
# Final output torch.Size([102, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 128])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([76, 64])
# Emb:  torch.Size([76, 64, 100])
# Output of LSTM:  torch.Size([76, 64, 128])
# Final output torch.Size([76, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 128])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([64, 64])
# Emb:  torch.Size([64, 64, 100])
# Output of LSTM:  torch.Size([64, 64, 128])
# Final output torch.Size([64, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 128])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([82, 64])
# Emb:  torch.Size([82, 64, 100])
# Output of LSTM:  torch.Size([82, 64, 128])
# Final output torch.Size([82, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 128])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([72, 64])
# Emb:  torch.Size([72, 64, 100])
# Output of LSTM:  torch.Size([72, 64, 128])
# Final output torch.Size([72, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([83, 64])
# Emb:  torch.Size([83, 64, 100])
# Output of LSTM:  torch.Size([83, 64, 128])
# Final output torch.Size([83, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 128])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([83, 64])
# Emb:  torch.Size([83, 64, 100])
# Output of LSTM:  torch.Size([83, 64, 128])
# Final output torch.Size([83, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([59, 64])
# Emb:  torch.Size([59, 64, 100])
# Output of LSTM:  torch.Size([59, 64, 128])
# Final output torch.Size([59, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([44, 64])
# Emb:  torch.Size([44, 64, 100])
# Output of LSTM:  torch.Size([44, 64, 128])
# Final output torch.Size([44, 64, 13])
# Inputs:  torch.Size([54, 64])
# Emb:  torch.Size([54, 64, 100])
# Output of LSTM:  torch.Size([54, 64, 128])
# Final output torch.Size([54, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([77, 64])
# Emb:  torch.Size([77, 64, 100])
# Output of LSTM:  torch.Size([77, 64, 128])
# Final output torch.Size([77, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 128])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([75, 64])
# Emb:  torch.Size([75, 64, 100])
# Output of LSTM:  torch.Size([75, 64, 128])
# Final output torch.Size([75, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([59, 64])
# Emb:  torch.Size([59, 64, 100])
# Output of LSTM:  torch.Size([59, 64, 128])
# Final output torch.Size([59, 64, 13])
# Inputs:  torch.Size([70, 64])
# Emb:  torch.Size([70, 64, 100])
# Output of LSTM:  torch.Size([70, 64, 128])
# Final output torch.Size([70, 64, 13])
# Inputs:  torch.Size([79, 64])
# Emb:  torch.Size([79, 64, 100])
# Output of LSTM:  torch.Size([79, 64, 128])
# Final output torch.Size([79, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 128])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([69, 64])
# Emb:  torch.Size([69, 64, 100])
# Output of LSTM:  torch.Size([69, 64, 128])
# Final output torch.Size([69, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([77, 64])
# Emb:  torch.Size([77, 64, 100])
# Output of LSTM:  torch.Size([77, 64, 128])
# Final output torch.Size([77, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 128])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([78, 64])
# Emb:  torch.Size([78, 64, 100])
# Output of LSTM:  torch.Size([78, 64, 128])
# Final output torch.Size([78, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 128])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([64, 64])
# Emb:  torch.Size([64, 64, 100])
# Output of LSTM:  torch.Size([64, 64, 128])
# Final output torch.Size([64, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 128])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([54, 64])
# Emb:  torch.Size([54, 64, 100])
# Output of LSTM:  torch.Size([54, 64, 128])
# Final output torch.Size([54, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 128])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 128])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([96, 64])
# Emb:  torch.Size([96, 64, 100])
# Output of LSTM:  torch.Size([96, 64, 128])
# Final output torch.Size([96, 64, 13])
# Inputs:  torch.Size([47, 64])
# Emb:  torch.Size([47, 64, 100])
# Output of LSTM:  torch.Size([47, 64, 128])
# Final output torch.Size([47, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([98, 64])
# Emb:  torch.Size([98, 64, 100])
# Output of LSTM:  torch.Size([98, 64, 128])
# Final output torch.Size([98, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 128])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([79, 64])
# Emb:  torch.Size([79, 64, 100])
# Output of LSTM:  torch.Size([79, 64, 128])
# Final output torch.Size([79, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([47, 64])
# Emb:  torch.Size([47, 64, 100])
# Output of LSTM:  torch.Size([47, 64, 128])
# Final output torch.Size([47, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 128])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 128])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 128])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 128])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([47, 64])
# Emb:  torch.Size([47, 64, 100])
# Output of LSTM:  torch.Size([47, 64, 128])
# Final output torch.Size([47, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([113, 64])
# Emb:  torch.Size([113, 64, 100])
# Output of LSTM:  torch.Size([113, 64, 128])
# Final output torch.Size([113, 64, 13])
# Inputs:  torch.Size([47, 64])
# Emb:  torch.Size([47, 64, 100])
# Output of LSTM:  torch.Size([47, 64, 128])
# Final output torch.Size([47, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 128])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([145, 64])
# Emb:  torch.Size([145, 64, 100])
# Output of LSTM:  torch.Size([145, 64, 128])
# Final output torch.Size([145, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([44, 64])
# Emb:  torch.Size([44, 64, 100])
# Output of LSTM:  torch.Size([44, 64, 128])
# Final output torch.Size([44, 64, 13])
# Inputs:  torch.Size([104, 63])
# Emb:  torch.Size([104, 63, 100])
# Output of LSTM:  torch.Size([104, 63, 128])
# Final output torch.Size([104, 63, 13])
# Test accuracy is 95.62397364262624 %

# %% [markdown]
# ### Bidirectional LSTM
#
# Благодаря BiLSTM можно использовать сразу оба контеста при предсказании тега слова. Т.е. для каждого токена $w_i$ forward LSTM будет выдавать представление $\mathbf{f_i} \sim (w_1, \ldots, w_i)$ - построенное по всему левому контексту - и $\mathbf{b_i} \sim (w_n, \ldots, w_i)$ - представление правого контекста. Их конкатенация автоматически захватит весь доступный контекст слова: $\mathbf{h_i} = [\mathbf{f_i}, \mathbf{b_i}] \sim (w_1, \ldots, w_n)$.
#
# ![BiLSTM](https://www.researchgate.net/profile/Wang_Ling/publication/280912217/figure/fig2/AS:391505383575555@1470353565299/Illustration-of-our-neural-network-for-POS-tagging.png)
# *From [Finding Function in Form: Compositional Character Models for Open Vocabulary Word Representation](https://arxiv.org/abs/1508.02096)*
#
# **Задание** Добавьте Bidirectional LSTM.

# %%
class BidirectionalLSTMTagger(nn.Module):
    def __init__(self, vocab_size, tagset_size, word_emb_dim=100, lstm_hidden_dim=128, lstm_layers_count=1):
        super().__init__()
        
        self._emb = nn.Embedding(vocab_size, word_emb_dim)
        self._lstm = nn.LSTM(word_emb_dim, lstm_hidden_dim, num_layers=lstm_layers_count, bidirectional = True)
        self._out_layer = nn.Linear(2*lstm_hidden_dim, tagset_size)

    def forward(self, inputs):
        print("Inputs: ", inputs.shape)
        emb = self._emb(inputs)
        print("Emb: ", emb.shape)
        output, _ = self._lstm(emb)
        print("Output of LSTM: ", output.shape)
        out = self._out_layer(output)
        print("Final output", out.shape)
        return out

# %%
model = BidirectionalLSTMTagger(
    lstm_layers_count=2,
    vocab_size=len(word2ind),
    tagset_size=len(tag2ind)
).cuda()

criterion = nn.CrossEntropyLoss(ignore_index = 0).cuda()
optimizer = optim.Adam(model.parameters(), lr = 5e-3, weight_decay = 5e-4)

fit(model, criterion, optimizer, train_data=(X_train, y_train), epochs_count=50, batch_size=64, val_data=(X_val, y_val), val_batch_size=512)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
test_ac =  compute_accuracy(model, (X_test, y_test))
print(f'Test accuracy for biderectional LSTM is {test_ac * 100} %')
# Out:
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 256])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([64, 64])
# Emb:  torch.Size([64, 64, 100])
# Output of LSTM:  torch.Size([64, 64, 256])
# Final output torch.Size([64, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 256])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 256])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 256])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 256])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 256])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 256])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([90, 64])
# Emb:  torch.Size([90, 64, 100])
# Output of LSTM:  torch.Size([90, 64, 256])
# Final output torch.Size([90, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 256])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 256])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([79, 64])
# Emb:  torch.Size([79, 64, 100])
# Output of LSTM:  torch.Size([79, 64, 256])
# Final output torch.Size([79, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 256])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 256])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 256])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 256])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([70, 64])
# Emb:  torch.Size([70, 64, 100])
# Output of LSTM:  torch.Size([70, 64, 256])
# Final output torch.Size([70, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 256])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([69, 64])
# Emb:  torch.Size([69, 64, 100])
# Output of LSTM:  torch.Size([69, 64, 256])
# Final output torch.Size([69, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 256])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 256])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([72, 64])
# Emb:  torch.Size([72, 64, 100])
# Output of LSTM:  torch.Size([72, 64, 256])
# Final output torch.Size([72, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 256])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 256])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 256])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 256])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 256])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([47, 64])
# Emb:  torch.Size([47, 64, 100])
# Output of LSTM:  torch.Size([47, 64, 256])
# Final output torch.Size([47, 64, 13])
# Inputs:  torch.Size([75, 64])
# Emb:  torch.Size([75, 64, 100])
# Output of LSTM:  torch.Size([75, 64, 256])
# Final output torch.Size([75, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 256])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 256])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 256])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([104, 64])
# Emb:  torch.Size([104, 64, 100])
# Output of LSTM:  torch.Size([104, 64, 256])
# Final output torch.Size([104, 64, 13])
# Inputs:  torch.Size([82, 64])
# Emb:  torch.Size([82, 64, 100])
# Output of LSTM:  torch.Size([82, 64, 256])
# Final output torch.Size([82, 64, 13])
# Inputs:  torch.Size([77, 64])
# Emb:  torch.Size([77, 64, 100])
# Output of LSTM:  torch.Size([77, 64, 256])
# Final output torch.Size([77, 64, 13])
# Inputs:  torch.Size([80, 64])
# Emb:  torch.Size([80, 64, 100])
# Output of LSTM:  torch.Size([80, 64, 256])
# Final output torch.Size([80, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 256])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 256])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([38, 64])
# Emb:  torch.Size([38, 64, 100])
# Output of LSTM:  torch.Size([38, 64, 256])
# Final output torch.Size([38, 64, 13])
# Inputs:  torch.Size([145, 64])
# Emb:  torch.Size([145, 64, 100])
# Output of LSTM:  torch.Size([145, 64, 256])
# Final output torch.Size([145, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 256])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 256])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([77, 64])
# Emb:  torch.Size([77, 64, 100])
# Output of LSTM:  torch.Size([77, 64, 256])
# Final output torch.Size([77, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 256])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([59, 64])
# Emb:  torch.Size([59, 64, 100])
# Output of LSTM:  torch.Size([59, 64, 256])
# Final output torch.Size([59, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 256])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 256])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 256])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([84, 64])
# Emb:  torch.Size([84, 64, 100])
# Output of LSTM:  torch.Size([84, 64, 256])
# Final output torch.Size([84, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 256])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 256])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 256])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([59, 64])
# Emb:  torch.Size([59, 64, 100])
# Output of LSTM:  torch.Size([59, 64, 256])
# Final output torch.Size([59, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 256])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 256])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 256])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 256])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([96, 64])
# Emb:  torch.Size([96, 64, 100])
# Output of LSTM:  torch.Size([96, 64, 256])
# Final output torch.Size([96, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 256])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([64, 64])
# Emb:  torch.Size([64, 64, 100])
# Output of LSTM:  torch.Size([64, 64, 256])
# Final output torch.Size([64, 64, 13])
# Inputs:  torch.Size([64, 64])
# Emb:  torch.Size([64, 64, 100])
# Output of LSTM:  torch.Size([64, 64, 256])
# Final output torch.Size([64, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 256])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 256])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([59, 64])
# Emb:  torch.Size([59, 64, 100])
# Output of LSTM:  torch.Size([59, 64, 256])
# Final output torch.Size([59, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 256])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 256])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 256])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([98, 64])
# Emb:  torch.Size([98, 64, 100])
# Output of LSTM:  torch.Size([98, 64, 256])
# Final output torch.Size([98, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 256])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([113, 64])
# Emb:  torch.Size([113, 64, 100])
# Output of LSTM:  torch.Size([113, 64, 256])
# Final output torch.Size([113, 64, 13])
# Inputs:  torch.Size([44, 64])
# Emb:  torch.Size([44, 64, 100])
# Output of LSTM:  torch.Size([44, 64, 256])
# Final output torch.Size([44, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 256])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([43, 64])
# Emb:  torch.Size([43, 64, 100])
# Output of LSTM:  torch.Size([43, 64, 256])
# Final output torch.Size([43, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 256])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 256])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([46, 64])
# Emb:  torch.Size([46, 64, 100])
# Output of LSTM:  torch.Size([46, 64, 256])
# Final output torch.Size([46, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 256])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 256])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([82, 64])
# Emb:  torch.Size([82, 64, 100])
# Output of LSTM:  torch.Size([82, 64, 256])
# Final output torch.Size([82, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 256])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 256])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 256])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 256])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 256])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([82, 64])
# Emb:  torch.Size([82, 64, 100])
# Output of LSTM:  torch.Size([82, 64, 256])
# Final output torch.Size([82, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 256])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 256])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 256])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([96, 64])
# Emb:  torch.Size([96, 64, 100])
# Output of LSTM:  torch.Size([96, 64, 256])
# Final output torch.Size([96, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 256])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([59, 64])
# Emb:  torch.Size([59, 64, 100])
# Output of LSTM:  torch.Size([59, 64, 256])
# Final output torch.Size([59, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 256])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 256])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 256])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([113, 64])
# Emb:  torch.Size([113, 64, 100])
# Output of LSTM:  torch.Size([113, 64, 256])
# Final output torch.Size([113, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 256])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 256])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([47, 64])
# Emb:  torch.Size([47, 64, 100])
# Output of LSTM:  torch.Size([47, 64, 256])
# Final output torch.Size([47, 64, 13])
# Inputs:  torch.Size([102, 64])
# Emb:  torch.Size([102, 64, 100])
# Output of LSTM:  torch.Size([102, 64, 256])
# Final output torch.Size([102, 64, 13])
# Inputs:  torch.Size([47, 64])
# Emb:  torch.Size([47, 64, 100])
# Output of LSTM:  torch.Size([47, 64, 256])
# Final output torch.Size([47, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 256])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 256])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 256])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([72, 64])
# Emb:  torch.Size([72, 64, 100])
# Output of LSTM:  torch.Size([72, 64, 256])
# Final output torch.Size([72, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 256])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 256])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([45, 64])
# Emb:  torch.Size([45, 64, 100])
# Output of LSTM:  torch.Size([45, 64, 256])
# Final output torch.Size([45, 64, 13])
# Inputs:  torch.Size([141, 64])
# Emb:  torch.Size([141, 64, 100])
# Output of LSTM:  torch.Size([141, 64, 256])
# Final output torch.Size([141, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 256])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 256])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 256])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([72, 64])
# Emb:  torch.Size([72, 64, 100])
# Output of LSTM:  torch.Size([72, 64, 256])
# Final output torch.Size([72, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 256])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 256])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([69, 64])
# Emb:  torch.Size([69, 64, 100])
# Output of LSTM:  torch.Size([69, 64, 256])
# Final output torch.Size([69, 64, 13])
# Inputs:  torch.Size([64, 64])
# Emb:  torch.Size([64, 64, 100])
# Output of LSTM:  torch.Size([64, 64, 256])
# Final output torch.Size([64, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 256])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 256])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 256])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([83, 64])
# Emb:  torch.Size([83, 64, 100])
# Output of LSTM:  torch.Size([83, 64, 256])
# Final output torch.Size([83, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 256])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 256])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([41, 64])
# Emb:  torch.Size([41, 64, 100])
# Output of LSTM:  torch.Size([41, 64, 256])
# Final output torch.Size([41, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 256])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([54, 64])
# Emb:  torch.Size([54, 64, 100])
# Output of LSTM:  torch.Size([54, 64, 256])
# Final output torch.Size([54, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 256])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([76, 64])
# Emb:  torch.Size([76, 64, 100])
# Output of LSTM:  torch.Size([76, 64, 256])
# Final output torch.Size([76, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 256])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([84, 64])
# Emb:  torch.Size([84, 64, 100])
# Output of LSTM:  torch.Size([84, 64, 256])
# Final output torch.Size([84, 64, 13])
# Inputs:  torch.Size([105, 64])
# Emb:  torch.Size([105, 64, 100])
# Output of LSTM:  torch.Size([105, 64, 256])
# Final output torch.Size([105, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 256])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 256])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 256])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 256])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 256])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 256])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 256])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([36, 64])
# Emb:  torch.Size([36, 64, 100])
# Output of LSTM:  torch.Size([36, 64, 256])
# Final output torch.Size([36, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 256])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([70, 64])
# Emb:  torch.Size([70, 64, 100])
# Output of LSTM:  torch.Size([70, 64, 256])
# Final output torch.Size([70, 64, 13])
# Inputs:  torch.Size([77, 64])
# Emb:  torch.Size([77, 64, 100])
# Output of LSTM:  torch.Size([77, 64, 256])
# Final output torch.Size([77, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 256])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 256])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([81, 64])
# Emb:  torch.Size([81, 64, 100])
# Output of LSTM:  torch.Size([81, 64, 256])
# Final output torch.Size([81, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 256])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 256])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 256])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 256])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([85, 64])
# Emb:  torch.Size([85, 64, 100])
# Output of LSTM:  torch.Size([85, 64, 256])
# Final output torch.Size([85, 64, 13])
# Inputs:  torch.Size([82, 64])
# Emb:  torch.Size([82, 64, 100])
# Output of LSTM:  torch.Size([82, 64, 256])
# Final output torch.Size([82, 64, 13])
# Inputs:  torch.Size([43, 64])
# Emb:  torch.Size([43, 64, 100])
# Output of LSTM:  torch.Size([43, 64, 256])
# Final output torch.Size([43, 64, 13])
# Inputs:  torch.Size([54, 64])
# Emb:  torch.Size([54, 64, 100])
# Output of LSTM:  torch.Size([54, 64, 256])
# Final output torch.Size([54, 64, 13])
# Inputs:  torch.Size([54, 64])
# Emb:  torch.Size([54, 64, 100])
# Output of LSTM:  torch.Size([54, 64, 256])
# Final output torch.Size([54, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 256])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 256])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 256])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 256])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 256])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 256])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([78, 64])
# Emb:  torch.Size([78, 64, 100])
# Output of LSTM:  torch.Size([78, 64, 256])
# Final output torch.Size([78, 64, 13])
# Inputs:  torch.Size([54, 64])
# Emb:  torch.Size([54, 64, 100])
# Output of LSTM:  torch.Size([54, 64, 256])
# Final output torch.Size([54, 64, 13])
# Inputs:  torch.Size([72, 64])
# Emb:  torch.Size([72, 64, 100])
# Output of LSTM:  torch.Size([72, 64, 256])
# Final output torch.Size([72, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 256])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 256])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([70, 64])
# Emb:  torch.Size([70, 64, 100])
# Output of LSTM:  torch.Size([70, 64, 256])
# Final output torch.Size([70, 64, 13])
# Inputs:  torch.Size([43, 64])
# Emb:  torch.Size([43, 64, 100])
# Output of LSTM:  torch.Size([43, 64, 256])
# Final output torch.Size([43, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 256])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 256])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([81, 64])
# Emb:  torch.Size([81, 64, 100])
# Output of LSTM:  torch.Size([81, 64, 256])
# Final output torch.Size([81, 64, 13])
# Inputs:  torch.Size([54, 64])
# Emb:  torch.Size([54, 64, 100])
# Output of LSTM:  torch.Size([54, 64, 256])
# Final output torch.Size([54, 64, 13])
# Inputs:  torch.Size([76, 64])
# Emb:  torch.Size([76, 64, 100])
# Output of LSTM:  torch.Size([76, 64, 256])
# Final output torch.Size([76, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 256])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([59, 64])
# Emb:  torch.Size([59, 64, 100])
# Output of LSTM:  torch.Size([59, 64, 256])
# Final output torch.Size([59, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 256])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 256])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 256])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([43, 64])
# Emb:  torch.Size([43, 64, 100])
# Output of LSTM:  torch.Size([43, 64, 256])
# Final output torch.Size([43, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 256])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([72, 64])
# Emb:  torch.Size([72, 64, 100])
# Output of LSTM:  torch.Size([72, 64, 256])
# Final output torch.Size([72, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 256])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 256])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 256])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 256])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([70, 64])
# Emb:  torch.Size([70, 64, 100])
# Output of LSTM:  torch.Size([70, 64, 256])
# Final output torch.Size([70, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 256])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([79, 64])
# Emb:  torch.Size([79, 64, 100])
# Output of LSTM:  torch.Size([79, 64, 256])
# Final output torch.Size([79, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 256])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 256])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 256])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 256])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 256])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 256])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([64, 64])
# Emb:  torch.Size([64, 64, 100])
# Output of LSTM:  torch.Size([64, 64, 256])
# Final output torch.Size([64, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 256])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 256])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 256])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([172, 64])
# Emb:  torch.Size([172, 64, 100])
# Output of LSTM:  torch.Size([172, 64, 256])
# Final output torch.Size([172, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 256])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 256])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([47, 64])
# Emb:  torch.Size([47, 64, 100])
# Output of LSTM:  torch.Size([47, 64, 256])
# Final output torch.Size([47, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 256])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([96, 64])
# Emb:  torch.Size([96, 64, 100])
# Output of LSTM:  torch.Size([96, 64, 256])
# Final output torch.Size([96, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 256])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 256])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 256])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 256])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 256])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([47, 64])
# Emb:  torch.Size([47, 64, 100])
# Output of LSTM:  torch.Size([47, 64, 256])
# Final output torch.Size([47, 64, 13])
# Inputs:  torch.Size([146, 64])
# Emb:  torch.Size([146, 64, 100])
# Output of LSTM:  torch.Size([146, 64, 256])
# Final output torch.Size([146, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 256])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([76, 64])
# Emb:  torch.Size([76, 64, 100])
# Output of LSTM:  torch.Size([76, 64, 256])
# Final output torch.Size([76, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 256])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([83, 64])
# Emb:  torch.Size([83, 64, 100])
# Output of LSTM:  torch.Size([83, 64, 256])
# Final output torch.Size([83, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 256])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([75, 64])
# Emb:  torch.Size([75, 64, 100])
# Output of LSTM:  torch.Size([75, 64, 256])
# Final output torch.Size([75, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 256])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([78, 64])
# Emb:  torch.Size([78, 64, 100])
# Output of LSTM:  torch.Size([78, 64, 256])
# Final output torch.Size([78, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 256])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([46, 64])
# Emb:  torch.Size([46, 64, 100])
# Output of LSTM:  torch.Size([46, 64, 256])
# Final output torch.Size([46, 64, 13])
# Inputs:  torch.Size([83, 64])
# Emb:  torch.Size([83, 64, 100])
# Output of LSTM:  torch.Size([83, 64, 256])
# Final output torch.Size([83, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 256])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 256])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 256])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([58, 63])
# Emb:  torch.Size([58, 63, 100])
# Output of LSTM:  torch.Size([58, 63, 256])
# Final output torch.Size([58, 63, 13])
# Test accuracy for biderectional LSTM is 96.86747983433688 %

# %% [markdown]
# ### Предобученные эмбеддинги
#
# Мы знаем, какая клёвая вещь - предобученные эмбеддинги. При текущем размере обучающей выборки еще можно было учить их и с нуля - с меньшей было бы совсем плохо.
#
# Поэтому стандартный пайплайн - скачать эмбеддинги, засунуть их в сеточку. Запустим его:

# %%
import gensim.downloader as api

w2v_model = api.load('glove-wiki-gigaword-100')

# %% [markdown]
# Построим подматрицу для слов из нашей тренировочной выборки:

# %%
known_count = 0
embeddings = np.zeros((len(word2ind), w2v_model.vectors.shape[1]))
for word, ind in word2ind.items():
    word = word.lower()
    if word in w2v_model.vocab:
        embeddings[ind] = w2v_model.get_vector(word)
        known_count += 1
        
print('Know {} out of {} word embeddings'.format(known_count, len(word2ind)))
# Out:
# Know 38736 out of 45441 word embeddings

# %% [markdown]
# **Задание** Сделайте модель с предобученной матрицей. Используйте `nn.Embedding.from_pretrained`.

# %%
class LSTMTaggerWithPretrainedEmbs(nn.Module):
    def __init__(self, embeddings, tagset_size, lstm_hidden_dim=64, lstm_layers_count=1):
        super().__init__()
        
        self._emb = nn.Embedding.from_pretrained(embeddings)
        self._lstm = nn.LSTM(embeddings.shape[1], lstm_hidden_dim, num_layers=lstm_layers_count, bidirectional = True)
        self._out_layer = nn.Linear(2*lstm_hidden_dim, tagset_size)

    def forward(self, inputs):
        print("Inputs: ", inputs.shape)
        emb = self._emb(inputs)
        print("Emb: ", emb.shape)
        output, _ = self._lstm(emb)
        print("Output of LSTM: ", output.shape)
        out = self._out_layer(output)
        print("Final output", out.shape)
        return out

# %%
model = LSTMTaggerWithPretrainedEmbs(
    lstm_layers_count=2,
    embeddings=torch.FloatTensor(embeddings),
    tagset_size=len(tag2ind)
).cuda()

criterion = nn.CrossEntropyLoss(ignore_index=0)
optimizer = optim.Adam(model.parameters(), lr = 5e-3, weight_decay = 5e-4)

fit(model, criterion, optimizer, train_data=(X_train, y_train), epochs_count=50,
    batch_size=64, val_data=(X_val, y_val), val_batch_size=512)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Задание** Оцените качество модели на тестовой выборке. Обратите внимание, вовсе не обязательно ограничиваться векторами из урезанной матрицы - вполне могут найтись слова в тесте, которых не было в трейне и для которых есть эмбеддинги.
#
# Добейтесь качества лучше прошлых моделей.

# %%
test_ac =  compute_accuracy(model, (X_test, y_test))
print(f'Test accuracy for biderectional LSTM with pretrained embeddings is {test_ac * 100} %')
# Out:
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([54, 64])
# Emb:  torch.Size([54, 64, 100])
# Output of LSTM:  torch.Size([54, 64, 128])
# Final output torch.Size([54, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 128])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([43, 64])
# Emb:  torch.Size([43, 64, 100])
# Output of LSTM:  torch.Size([43, 64, 128])
# Final output torch.Size([43, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 128])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([96, 64])
# Emb:  torch.Size([96, 64, 100])
# Output of LSTM:  torch.Size([96, 64, 128])
# Final output torch.Size([96, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([82, 64])
# Emb:  torch.Size([82, 64, 100])
# Output of LSTM:  torch.Size([82, 64, 128])
# Final output torch.Size([82, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 128])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([72, 64])
# Emb:  torch.Size([72, 64, 100])
# Output of LSTM:  torch.Size([72, 64, 128])
# Final output torch.Size([72, 64, 13])
# Inputs:  torch.Size([77, 64])
# Emb:  torch.Size([77, 64, 100])
# Output of LSTM:  torch.Size([77, 64, 128])
# Final output torch.Size([77, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([70, 64])
# Emb:  torch.Size([70, 64, 100])
# Output of LSTM:  torch.Size([70, 64, 128])
# Final output torch.Size([70, 64, 13])
# Inputs:  torch.Size([85, 64])
# Emb:  torch.Size([85, 64, 100])
# Output of LSTM:  torch.Size([85, 64, 128])
# Final output torch.Size([85, 64, 13])
# Inputs:  torch.Size([96, 64])
# Emb:  torch.Size([96, 64, 100])
# Output of LSTM:  torch.Size([96, 64, 128])
# Final output torch.Size([96, 64, 13])
# Inputs:  torch.Size([81, 64])
# Emb:  torch.Size([81, 64, 100])
# Output of LSTM:  torch.Size([81, 64, 128])
# Final output torch.Size([81, 64, 13])
# Inputs:  torch.Size([104, 64])
# Emb:  torch.Size([104, 64, 100])
# Output of LSTM:  torch.Size([104, 64, 128])
# Final output torch.Size([104, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([59, 64])
# Emb:  torch.Size([59, 64, 100])
# Output of LSTM:  torch.Size([59, 64, 128])
# Final output torch.Size([59, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 128])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([47, 64])
# Emb:  torch.Size([47, 64, 100])
# Output of LSTM:  torch.Size([47, 64, 128])
# Final output torch.Size([47, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([47, 64])
# Emb:  torch.Size([47, 64, 100])
# Output of LSTM:  torch.Size([47, 64, 128])
# Final output torch.Size([47, 64, 13])
# Inputs:  torch.Size([41, 64])
# Emb:  torch.Size([41, 64, 100])
# Output of LSTM:  torch.Size([41, 64, 128])
# Final output torch.Size([41, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 128])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([45, 64])
# Emb:  torch.Size([45, 64, 100])
# Output of LSTM:  torch.Size([45, 64, 128])
# Final output torch.Size([45, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 128])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([96, 64])
# Emb:  torch.Size([96, 64, 100])
# Output of LSTM:  torch.Size([96, 64, 128])
# Final output torch.Size([96, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([54, 64])
# Emb:  torch.Size([54, 64, 100])
# Output of LSTM:  torch.Size([54, 64, 128])
# Final output torch.Size([54, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([64, 64])
# Emb:  torch.Size([64, 64, 100])
# Output of LSTM:  torch.Size([64, 64, 128])
# Final output torch.Size([64, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([84, 64])
# Emb:  torch.Size([84, 64, 100])
# Output of LSTM:  torch.Size([84, 64, 128])
# Final output torch.Size([84, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([44, 64])
# Emb:  torch.Size([44, 64, 100])
# Output of LSTM:  torch.Size([44, 64, 128])
# Final output torch.Size([44, 64, 13])
# Inputs:  torch.Size([64, 64])
# Emb:  torch.Size([64, 64, 100])
# Output of LSTM:  torch.Size([64, 64, 128])
# Final output torch.Size([64, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([39, 64])
# Emb:  torch.Size([39, 64, 100])
# Output of LSTM:  torch.Size([39, 64, 128])
# Final output torch.Size([39, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([75, 64])
# Emb:  torch.Size([75, 64, 100])
# Output of LSTM:  torch.Size([75, 64, 128])
# Final output torch.Size([75, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 128])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([83, 64])
# Emb:  torch.Size([83, 64, 100])
# Output of LSTM:  torch.Size([83, 64, 128])
# Final output torch.Size([83, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([79, 64])
# Emb:  torch.Size([79, 64, 100])
# Output of LSTM:  torch.Size([79, 64, 128])
# Final output torch.Size([79, 64, 13])
# Inputs:  torch.Size([37, 64])
# Emb:  torch.Size([37, 64, 100])
# Output of LSTM:  torch.Size([37, 64, 128])
# Final output torch.Size([37, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 128])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 128])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([82, 64])
# Emb:  torch.Size([82, 64, 100])
# Output of LSTM:  torch.Size([82, 64, 128])
# Final output torch.Size([82, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([82, 64])
# Emb:  torch.Size([82, 64, 100])
# Output of LSTM:  torch.Size([82, 64, 128])
# Final output torch.Size([82, 64, 13])
# Inputs:  torch.Size([113, 64])
# Emb:  torch.Size([113, 64, 100])
# Output of LSTM:  torch.Size([113, 64, 128])
# Final output torch.Size([113, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 128])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([59, 64])
# Emb:  torch.Size([59, 64, 100])
# Output of LSTM:  torch.Size([59, 64, 128])
# Final output torch.Size([59, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 128])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([45, 64])
# Emb:  torch.Size([45, 64, 100])
# Output of LSTM:  torch.Size([45, 64, 128])
# Final output torch.Size([45, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 128])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([64, 64])
# Emb:  torch.Size([64, 64, 100])
# Output of LSTM:  torch.Size([64, 64, 128])
# Final output torch.Size([64, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([54, 64])
# Emb:  torch.Size([54, 64, 100])
# Output of LSTM:  torch.Size([54, 64, 128])
# Final output torch.Size([54, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([44, 64])
# Emb:  torch.Size([44, 64, 100])
# Output of LSTM:  torch.Size([44, 64, 128])
# Final output torch.Size([44, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 128])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 128])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([145, 64])
# Emb:  torch.Size([145, 64, 100])
# Output of LSTM:  torch.Size([145, 64, 128])
# Final output torch.Size([145, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([72, 64])
# Emb:  torch.Size([72, 64, 100])
# Output of LSTM:  torch.Size([72, 64, 128])
# Final output torch.Size([72, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([141, 64])
# Emb:  torch.Size([141, 64, 100])
# Output of LSTM:  torch.Size([141, 64, 128])
# Final output torch.Size([141, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 128])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 128])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([81, 64])
# Emb:  torch.Size([81, 64, 100])
# Output of LSTM:  torch.Size([81, 64, 128])
# Final output torch.Size([81, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([105, 64])
# Emb:  torch.Size([105, 64, 100])
# Output of LSTM:  torch.Size([105, 64, 128])
# Final output torch.Size([105, 64, 13])
# Inputs:  torch.Size([146, 64])
# Emb:  torch.Size([146, 64, 100])
# Output of LSTM:  torch.Size([146, 64, 128])
# Final output torch.Size([146, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([69, 64])
# Emb:  torch.Size([69, 64, 100])
# Output of LSTM:  torch.Size([69, 64, 128])
# Final output torch.Size([69, 64, 13])
# Inputs:  torch.Size([79, 64])
# Emb:  torch.Size([79, 64, 100])
# Output of LSTM:  torch.Size([79, 64, 128])
# Final output torch.Size([79, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([83, 64])
# Emb:  torch.Size([83, 64, 100])
# Output of LSTM:  torch.Size([83, 64, 128])
# Final output torch.Size([83, 64, 13])
# Inputs:  torch.Size([70, 64])
# Emb:  torch.Size([70, 64, 100])
# Output of LSTM:  torch.Size([70, 64, 128])
# Final output torch.Size([70, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([59, 64])
# Emb:  torch.Size([59, 64, 100])
# Output of LSTM:  torch.Size([59, 64, 128])
# Final output torch.Size([59, 64, 13])
# Inputs:  torch.Size([82, 64])
# Emb:  torch.Size([82, 64, 100])
# Output of LSTM:  torch.Size([82, 64, 128])
# Final output torch.Size([82, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([47, 64])
# Emb:  torch.Size([47, 64, 100])
# Output of LSTM:  torch.Size([47, 64, 128])
# Final output torch.Size([47, 64, 13])
# Inputs:  torch.Size([69, 64])
# Emb:  torch.Size([69, 64, 100])
# Output of LSTM:  torch.Size([69, 64, 128])
# Final output torch.Size([69, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 128])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([51, 64])
# Emb:  torch.Size([51, 64, 100])
# Output of LSTM:  torch.Size([51, 64, 128])
# Final output torch.Size([51, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 128])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([83, 64])
# Emb:  torch.Size([83, 64, 100])
# Output of LSTM:  torch.Size([83, 64, 128])
# Final output torch.Size([83, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([70, 64])
# Emb:  torch.Size([70, 64, 100])
# Output of LSTM:  torch.Size([70, 64, 128])
# Final output torch.Size([70, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 128])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([90, 64])
# Emb:  torch.Size([90, 64, 100])
# Output of LSTM:  torch.Size([90, 64, 128])
# Final output torch.Size([90, 64, 13])
# Inputs:  torch.Size([102, 64])
# Emb:  torch.Size([102, 64, 100])
# Output of LSTM:  torch.Size([102, 64, 128])
# Final output torch.Size([102, 64, 13])
# Inputs:  torch.Size([76, 64])
# Emb:  torch.Size([76, 64, 100])
# Output of LSTM:  torch.Size([76, 64, 128])
# Final output torch.Size([76, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([70, 64])
# Emb:  torch.Size([70, 64, 100])
# Output of LSTM:  torch.Size([70, 64, 128])
# Final output torch.Size([70, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 128])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([61, 64])
# Emb:  torch.Size([61, 64, 100])
# Output of LSTM:  torch.Size([61, 64, 128])
# Final output torch.Size([61, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 128])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([65, 64])
# Emb:  torch.Size([65, 64, 100])
# Output of LSTM:  torch.Size([65, 64, 128])
# Final output torch.Size([65, 64, 13])
# Inputs:  torch.Size([113, 64])
# Emb:  torch.Size([113, 64, 100])
# Output of LSTM:  torch.Size([113, 64, 128])
# Final output torch.Size([113, 64, 13])
# Inputs:  torch.Size([78, 64])
# Emb:  torch.Size([78, 64, 100])
# Output of LSTM:  torch.Size([78, 64, 128])
# Final output torch.Size([78, 64, 13])
# Inputs:  torch.Size([77, 64])
# Emb:  torch.Size([77, 64, 100])
# Output of LSTM:  torch.Size([77, 64, 128])
# Final output torch.Size([77, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([80, 64])
# Emb:  torch.Size([80, 64, 100])
# Output of LSTM:  torch.Size([80, 64, 128])
# Final output torch.Size([80, 64, 13])
# Inputs:  torch.Size([98, 64])
# Emb:  torch.Size([98, 64, 100])
# Output of LSTM:  torch.Size([98, 64, 128])
# Final output torch.Size([98, 64, 13])
# Inputs:  torch.Size([58, 64])
# Emb:  torch.Size([58, 64, 100])
# Output of LSTM:  torch.Size([58, 64, 128])
# Final output torch.Size([58, 64, 13])
# Inputs:  torch.Size([79, 64])
# Emb:  torch.Size([79, 64, 100])
# Output of LSTM:  torch.Size([79, 64, 128])
# Final output torch.Size([79, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 128])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 128])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([172, 64])
# Emb:  torch.Size([172, 64, 100])
# Output of LSTM:  torch.Size([172, 64, 128])
# Final output torch.Size([172, 64, 13])
# Inputs:  torch.Size([67, 64])
# Emb:  torch.Size([67, 64, 100])
# Output of LSTM:  torch.Size([67, 64, 128])
# Final output torch.Size([67, 64, 13])
# Inputs:  torch.Size([59, 64])
# Emb:  torch.Size([59, 64, 100])
# Output of LSTM:  torch.Size([59, 64, 128])
# Final output torch.Size([59, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 128])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([50, 64])
# Emb:  torch.Size([50, 64, 100])
# Output of LSTM:  torch.Size([50, 64, 128])
# Final output torch.Size([50, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([72, 64])
# Emb:  torch.Size([72, 64, 100])
# Output of LSTM:  torch.Size([72, 64, 128])
# Final output torch.Size([72, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([84, 64])
# Emb:  torch.Size([84, 64, 100])
# Output of LSTM:  torch.Size([84, 64, 128])
# Final output torch.Size([84, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 128])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([76, 64])
# Emb:  torch.Size([76, 64, 100])
# Output of LSTM:  torch.Size([76, 64, 128])
# Final output torch.Size([76, 64, 13])
# Inputs:  torch.Size([73, 64])
# Emb:  torch.Size([73, 64, 100])
# Output of LSTM:  torch.Size([73, 64, 128])
# Final output torch.Size([73, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 128])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([62, 64])
# Emb:  torch.Size([62, 64, 100])
# Output of LSTM:  torch.Size([62, 64, 128])
# Final output torch.Size([62, 64, 13])
# Inputs:  torch.Size([75, 64])
# Emb:  torch.Size([75, 64, 100])
# Output of LSTM:  torch.Size([75, 64, 128])
# Final output torch.Size([75, 64, 13])
# Inputs:  torch.Size([60, 64])
# Emb:  torch.Size([60, 64, 100])
# Output of LSTM:  torch.Size([60, 64, 128])
# Final output torch.Size([60, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 128])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([49, 64])
# Emb:  torch.Size([49, 64, 100])
# Output of LSTM:  torch.Size([49, 64, 128])
# Final output torch.Size([49, 64, 13])
# Inputs:  torch.Size([68, 64])
# Emb:  torch.Size([68, 64, 100])
# Output of LSTM:  torch.Size([68, 64, 128])
# Final output torch.Size([68, 64, 13])
# Inputs:  torch.Size([72, 64])
# Emb:  torch.Size([72, 64, 100])
# Output of LSTM:  torch.Size([72, 64, 128])
# Final output torch.Size([72, 64, 13])
# Inputs:  torch.Size([66, 64])
# Emb:  torch.Size([66, 64, 100])
# Output of LSTM:  torch.Size([66, 64, 128])
# Final output torch.Size([66, 64, 13])
# Inputs:  torch.Size([76, 64])
# Emb:  torch.Size([76, 64, 100])
# Output of LSTM:  torch.Size([76, 64, 128])
# Final output torch.Size([76, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([55, 64])
# Emb:  torch.Size([55, 64, 100])
# Output of LSTM:  torch.Size([55, 64, 128])
# Final output torch.Size([55, 64, 13])
# Inputs:  torch.Size([64, 64])
# Emb:  torch.Size([64, 64, 100])
# Output of LSTM:  torch.Size([64, 64, 128])
# Final output torch.Size([64, 64, 13])
# Inputs:  torch.Size([48, 64])
# Emb:  torch.Size([48, 64, 100])
# Output of LSTM:  torch.Size([48, 64, 128])
# Final output torch.Size([48, 64, 13])
# Inputs:  torch.Size([63, 64])
# Emb:  torch.Size([63, 64, 100])
# Output of LSTM:  torch.Size([63, 64, 128])
# Final output torch.Size([63, 64, 13])
# Inputs:  torch.Size([57, 64])
# Emb:  torch.Size([57, 64, 100])
# Output of LSTM:  torch.Size([57, 64, 128])
# Final output torch.Size([57, 64, 13])
# Inputs:  torch.Size([53, 64])
# Emb:  torch.Size([53, 64, 100])
# Output of LSTM:  torch.Size([53, 64, 128])
# Final output torch.Size([53, 64, 13])
# Inputs:  torch.Size([56, 64])
# Emb:  torch.Size([56, 64, 100])
# Output of LSTM:  torch.Size([56, 64, 128])
# Final output torch.Size([56, 64, 13])
# Inputs:  torch.Size([52, 64])
# Emb:  torch.Size([52, 64, 100])
# Output of LSTM:  torch.Size([52, 64, 128])
# Final output torch.Size([52, 64, 13])
# Inputs:  torch.Size([71, 64])
# Emb:  torch.Size([71, 64, 100])
# Output of LSTM:  torch.Size([71, 64, 128])
# Final output torch.Size([71, 64, 13])
# Inputs:  torch.Size([56, 63])
# Emb:  torch.Size([56, 63, 100])
# Output of LSTM:  torch.Size([56, 63, 128])
# Final output torch.Size([56, 63, 13])
# Test accuracy for biderectional LSTM with pretrained embeddings is 96.97420378766753 %
